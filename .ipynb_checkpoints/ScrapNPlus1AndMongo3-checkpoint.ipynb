# %% [markdown]
# Попробуем решить следующую задачу: нам необходимо выгрузить сайт NPlus1.ru и положить статьи в базу данных. Отдельно должны лежать идентификаторы загруженных текстов, словари начальных форм и токенов, разбиение текста на предложения. Для решения задачи будем использовать базу данных MongoDB.
#
# Импортируем все необходисые библиотеки. Обратите особое внимание на библиотеку для работы с Mongo - <a href="http://api.mongodb.com/python/current/api/index.html">pymongo</a>.

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import datetime
from tqdm import tqdm
import pymorphy2

import pymongo
from bson import ObjectId

delcom=re.compile("<!--.+-->", re.S)

# %% [markdown]
# Чтобы не ставить себе базу данных? будем использовать бесплатное облако <a href ="https://cloud.mongodb.com/">Mongo.Atlas</a>. Для этого необходимо зарегистрироваться, завести пользователя, создать проект, дать пользователю права на проект. Для пользователя получить строку для соединения с базой. Для работы с БД используем класс MongoClient, в который передаем строку соединения.

# %%
# Version after 3.6
client = pymongo.MongoClient('mongodb+srv://BKLuser:BKLPassword@cluster0-usd6h.mongodb.net/test?retryWrites=true&w=majority')

# %% [markdown]
# Аналогом реляционных записей являются документы. Аналогом таблиц - коллекции и подколлекции. Сам документ может включать в себя другие документы. Документ записывается в формате JSON, но для Питона можно считать, что это словари.<br>
# При помощи клиента обращаемся к базе `concordance2`. Если эта база не существовала, она создастся при первой записи данных. Аналогично всё происходит с коллекциями.<br>
#
# **Большая просьба к тем, кто решит делать что-то параллельно со мной!** Используйте, пожалуйста, базу `concordance2`, а то когда мы одновременно пишем одну и ту же новость, статистика меняется непредсказуемо, потом приходтся долго пытаться понять, отчего запрос не возвращает результаты, хотя только что прекрасно работал.
#
# В коллекции `nplus1texts` будем хранить адерса и идентификаторы текстов, в коллекции `dictionary` - словарь токенов, в `lemmas` - словарь лемм, наконец в `sentences` - разделение предложений на слова.

# %%
# Обращение к базе при помощи оператора квадратные скобки.
db = client['concordance2']
# Обращение к базе при помощи оператора точка.
#db = client.concordance2_1

# %% [markdown]
# Посмотрим что содержит в себе база.

# %%
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00-usd6h.mongodb.net:27017', 'cluster0-shard-00-01-usd6h.mongodb.net:27017', 'cluster0-shard-00-02-usd6h.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='Cluster0-shard-0', ssl=True, retrywrites=True, w='majority'), 'concordance2')

# %%
# Обращение к коллекции внутри базы при помощи оператора точка (но можно и при помощи квадратных скобок).
text_collection=db.nplus1texts
dictionary=db.dictionary
lemmas=db.lemmas
dbsents=db.sentences

# %%
# Добавляем индекс в коллекцию lemmas по полям iniForm и POS, оба по возрастанию.
# Заодно запрещаем добавлять повторяющиеся сочетания.
lemmas.create_index([('iniForm', pymongo.ASCENDING), ('POS', pymongo.ASCENDING)], unique=True)
dictionary.create_index([('token', pymongo.ASCENDING), ('iniForm', pymongo.ASCENDING), ('POS', pymongo.ASCENDING)], unique=True)
# Out:
# 'token_1_iniForm_1_POS_1'

# %%
# Для пробы чуть позже удалим индекс и посмотрим на изменение скорости работы.
lemmas.drop_index('iniForm_1_POS_1')

# %% [markdown]
# Напишем функцию для выгрузки одной статьи с сайта (это мы уже умеем).

# %%
class NPlus1Article:
    def __init__(self):
        self.time=""
        self.date=""
        self.rubr=""
        self.diff=""
        self.author=""
        self.head=""
        self.text=""

def getArticleTextNPlus1(adr):
    r = requests.get(adr)
    #print(r.text)
    art=NPlus1Article()
    tables=re.split("</div>",re.split('="tables"', r.text)[1])[0]
    t1=re.split("</time>", re.split("<time", tables)[1])[0]
    art.time=re.split("</span>", re.split("<span>", t1)[1])[0]
    art.date=re.split("</span>", re.split("<span>", t1)[2])[0]
    art.rubr=re.split(">", re.split("</a>", re.split("<a href", tables)[1])[0])[1]
    art.diff=re.split("</span>", re.split('"difficult-value">', tables)[1])[0]
    art.head=re.split("</h1>",re.split('<h1>', r.text)[1])[0]
    art.author=re.split('" />',re.split('<meta name="author" content="', r.text)[1])[0]
    art.text=re.split("</div>", re.split("</figure>", re.split('</article>',re.split('<article', r.text)[1])[0])[1])[1]    

    beaux_text=BeautifulSoup(art.text, "html5lib")
    art.text=delcom.sub("", beaux_text.get_text() )

    # print(art.n_time, art.n_date, art.n_rubr, art.n_diff)
    # print(art.n_head)
    # print(art.n_author)
    # print(art.n_text)
    #return [n_time, n_date, n_rubr, n_diff, n_author, n_head, n_text]
    return art

# %% [markdown]
# Для того, чтобы найти документ, необходимо использовать функцию `collection.find()`. Без параметров эта функция выдаст все документы.

# %%
for t in text_collection.find():
    print(t)
# Out:
# {'_id': ObjectId('5c92660268a3ff3428350cf2'), 'text_url': 'https://nplus1.ru/news/2015/04/06/gender-and-morality-', 'text_name': 'Психологи рассказали о влиянии пола на этические воззрения', 'art_text': 'Исследователи Кельнского, Техасского и Университета\xa0Уилфрида Лорье обнаружили корреляцию между полом и теми моральными принципами, на основании которых люди подходят к решению этических дилемм.\xa0Статья была опубликована\nв Personality and Social\nPsychology Bulletin.\n\nЭксперимент проводился на базе мета-анализа 40 исследований, в которых принимали\nучастие 6100 участников обоих полов. Участникам задавали 20 вопросов, которые\nпредставляли моральные дилеммы разной сложности. Среди них были вопросы об убийствах,\nпытках, лжи, абортах и экспериментах на животных: например, можно ли\nполицейскому пытать экстремиста-подрывника с целью получения информации о\nзаложенных бомбах? Было бы правильнее убить Адольфа Гитлера, пока он был\nмолодым австрийским художником, чтобы предотвратить Вторую мировую войну и\nспасти миллионы жизней?\n\nЭксперимент был спланирован так, чтобы противопоставлялись два философских подхода к этике. В деонтологии\n(нормативной этике), допустимость действия зависит от моральной нормы,\nвзятой за точку отсчета. Утилитаризм\nже, напротив, настаивает на том, что действие соответствует моральной норме,\nесли из него можно выжать максимальную пользу, всеобщее благо. С точки зрения\nутилитаризма, одно и то же действие моет быть нравственным в одной ситуации, и\nбезнравственным в другой, в зависимости от потенциального результата.\n\nИспользуя специальную статистическую процедуру\xa0удалось определить подсознательную склонность принимать те или иные решения. Оказалось, что женщины более склонны,\nчем мужчины, придерживаться деонтологических принципов (d = 0.57, то есть разница между средними примерно в два раза меньше, чем стандартное отклонение). При этом мужчины и женщины в равной степени руководствуются утилитаризмом.\xa0Из этого авторы делают вывод о том, что у женщин более сильное эмоциональное отторжение к причинению\nвреда, что и объясняет разницу в отношении к деонтологическому и утилитаристскому подходу.\xa0\n\nВлияние пола на этику исследуется не впервые. Исследователи\xa0Университете Квебека недавно попытались установить влияние внутриполовой конкуренции на моральные принципы (например, "Если перед вами стоит выбор - спасти трех\nпредставителей вашего пола или одного представителя противоположного, кого вы\nвыберите?"). Оказалось, что в большинстве случаев мужчины спасут противоположный пол, а женщины - оставят представительниц своего пола.\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_date':
Оказалось, что женщины более склонны,\nчем мужчины, придерживаться деонтологических принципов (d = 0.57, то есть разница между средними примерно в два раза меньше, чем стандартное отклонение). При этом мужчины и женщины в равной степени руководствуются утилитаризмом.\xa0Из этого авторы делают вывод о том, что у женщин более сильное эмоциональное отторжение к причинению\nвреда, что и объясняет разницу в отношении к деонтологическому и утилитаристскому подходу.\xa0\n\nВлияние пола на этику исследуется не впервые. Исследователи\xa0Университете Квебека недавно попытались установить влияние внутриполовой конкуренции на моральные принципы (например, "Если перед вами стоит выбор - спасти трех\nпредставителей вашего пола или одного представителя противоположного, кого вы\nвыберите?"). Оказалось, что в большинстве случаев мужчины спасут противоположный пол, а женщины - оставят представительниц своего пола.\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_time': '12:14', 'author': 'Юлия Минц', 'difficulty': '2.1', 'art_date': '06 Апр. 2015'}}
# {'_id': ObjectId('5c927935ec882c0d68f5326f'), 'text_name': 'F-35A впервые сбил воздушную цель', 'text_url': 'https://nplus1.ru/news/2016/08/02/target', 'art_text': 'Перспективный истребитель F-35A Lightning II во время испытаний на боевое применение впервые сбил воздушную цель. Как сообщает Flightglobal, испытание состоялось 28 июля 2016 года, однако известно об этом стало только сейчас. Во время проверки боевой самолет поразил беспилотную воздушную мишень.В проверке участвовал самолет с бортовым номером «AF-3». В полете радар истребителя обнаружил воздушную цель и передал целеуказание подвесному вооружению. После проверки данных летчик запустил ракету AIM-9X Sidewinder. Во время пуска ракеты мишень находилась выше линии прицеливания.F-35A также произвел запуск ракеты AIM-120C AMRAAM из внутреннего отсека вооружения. Эта ракета была запущена по беспилотнику-мишени, находившемуся за пределами прямой видимости. После запуска ракета подлетела близко к цели и самоуничтожилась, не поразив ее, как и было предусмотрено испытаниями.В настоящее время истребители F-35A проходят испытания на боевое применение, по итогам которых военные должны обнаружить как можно большее количество ошибок в работе программного обеспечения Block 3F. Оно делает возможным использование на истребителе подвесного вооружения и встроенной пушки. Это программное обеспечение после доработки будет установлено на самолеты в январе 2018 года.Разработка F-35 ведется с 2001 года. Самолет создается в трех базовых версиях: F-35A с обычным взлетом для ВВС, F-35B с укороченным взлетом и вертикальной посадкой для Морской пехоты и F-35C палубного базирования для ВМС. Морская пехота США уже приняла F-35B на вооружение, хотя в его программном обеспечении и содержатся восемь серьезных ошибок.Максимальная взлетная масса F-35 при длине 15,4 и размахе крыла 10,7 метра составляет 27,3 тонны. Самолет может развивать скорость до 1,9 тысячи километров в час, а его боевой радиус составляет 845 километров. F-35 может нести ракеты и бомбы и авиапушки общей массой до 8,1 тонны — 6,8 тонны на шести подкрыльевых точках подвески и 1,3 тонны на двух пилонах во внутренних отсеках вооружения.Василий Сычёв\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_time': '09:20', 'author': 'Василий Сычев', 'difficulty': '3.2', 'art_date': '02 Авг. 2016'}}

# %% [markdown]
# В качестве параметров функции передается документ (в случае Python - словарь) с полями и их значениями.
#
# Если значение должно отвечать не равенству, а другому условию, передается составное значение в виде словаря, ключем у которого будет обозначение оператора, а значением - значение с которым будет проводиться сравнение. Таких пар можно передать несколько.

# %%
# (freq _какое_ 2) _и_ (token _какое_ 'может')
#for l in dictionary.find({"freq": 2, 'token': 'может'}):
# token _какое_ 'может'
for l in dictionary.find({'token': 'может'}):
    print(l)
# Out:
# {'_id': ObjectId('5c9267a668a3ff3428351183'), 'token': 'может', 'iniForm': 'мочь', 'POS': 'VERB', 'freq': 2, 'docs': [ObjectId('5c9266ef68a3ff3428350fae')]}

# %%
# freq _какое_ меньше _чего_ 5
for l in lemmas.find({"freq":{"$gt": 5}})[:5]:
    print(l)

print("----")
# freq _какое_ меньше _чего_ 5
for l in dictionary.find({"freq":{"$gt": 5}})[:5]:
    print(l)
    
print("----")
# freq _какое_ ((больше _чего_ 5) _и_ (меньше _чего_ 9))
for l in dictionary.find({"freq":{"$gt": 5, "$lt": 9}})[:5]:
    print(l)
# Out:
# {'_id': ObjectId('5c9265d468a3ff3428350c38'), 'iniForm': 'сверхновый', 'POS': 'ADJF', 'freq': 7, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9276ceec882c0d68f52fb1')]}
# {'_id': ObjectId('5c9265d468a3ff3428350c3b'), 'iniForm': 'самый', 'POS': 'ADJF', 'freq': 6, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1')]}
# {'_id': ObjectId('5c9265d668a3ff3428350c41'), 'iniForm': 'из', 'POS': 'PREP', 'freq': 18, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'_id': ObjectId('5c9265d768a3ff3428350c47'), 'iniForm': 'с', 'POS': 'PREP', 'freq': 22, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5c927935ec882c0d68f5326f')]}
# {'_id': ObjectId('5c9265d868a3ff3428350c4a'), 'iniForm': 'момент', 'POS': 'NOUN', 'freq': 6, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c9276ceec882c0d68f52fb1')]}
# ----
# {'_id': ObjectId('5c9265d668a3ff3428350c42'), 'token': 'из', 'iniForm': 'из', 'POS': 'PREP', 'freq': 16, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'_id': ObjectId('5c9265d768a3ff3428350c48'), 'token': 'с', 'iniForm': 'с', 'POS': 'PREP', 'freq': 16, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5c927935ec882c0d68f5326f')]}
# {'_id': ObjectId('5c9265da68a3ff3428350c54'), 'token': 'и', 'iniForm': 'и', 'POS': 'CONJ', 'freq': 51, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5c927935ec882c0d68f5326f')]}
# {'_id': ObjectId('5c9265de68a3ff3428350c60'), 'token': 'в', 'iniForm': 'в', 'POS': 'PREP', 'freq': 71, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'_id': ObjectId('5c9265e668a3ff3428350c85'), 'token': 'на', 'iniForm': 'на', 'POS': 'PREP', 'freq': 40, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5c927935ec882c0d68f5326f')]}
# ----
# {'_id': ObjectId('5c9265e968a3ff3428350c91'), 'token': 'лет', 'iniForm': 'год', 'POS': 'NOUN', 'freq': 7, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1')]}
# {'_id': ObjectId('5c9265ee68a3ff3428350ca9'), 'token': 'был', 'iniForm': 'быть', 'POS': 'VERB', 'freq': 7, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'_id': ObjectId('5c9265fa68a3ff3428350cd5'), 'token': 'а', 'iniForm': 'а', 'POS': 'CONJ', 'freq': 7, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'_id': ObjectId('5c9265fe68a3ff3428350ce3'), 'token': 'или', 'iniForm': 'или', 'POS': 'CONJ', 'freq': 7, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'_id': ObjectId('5c92660368a3ff3428350cf4'), 'token': 'Исследователи', 'iniForm': 'исследователь', 'POS': 'NOUN', 'freq': 6, 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9277deec882c0d68f5314a')]}

# %%
# Можно записать и так.
# (freq _какое_ (больше _чего_ 5)() _и_ (freq _какое_ (меньше _чего_ 9))
for l in dictionary.find({"freq":{"$gt": 5}, "freq": {"$lt": 9}})[:5]:
    print(l)
# Out:
# {'_id': ObjectId('5c9265d368a3ff3428350c36'), 'token': 'эта', 'iniForm': 'этот', 'POS': 'ADJF', 'freq': 3, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1')]}
# {'_id': ObjectId('5c9265d468a3ff3428350c39'), 'token': 'сверхновая', 'iniForm': 'сверхновый', 'POS': 'ADJF', 'freq': 3, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9276ceec882c0d68f52fb1')]}
# {'_id': ObjectId('5c9265d568a3ff3428350c3c'), 'token': 'самая', 'iniForm': 'самый', 'POS': 'ADJF', 'freq': 3, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9276ceec882c0d68f52fb1')]}
# {'_id': ObjectId('5c9265d568a3ff3428350c3f'), 'token': 'близкая', 'iniForm': 'близкий', 'POS': 'ADJF', 'freq': 3, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9276ceec882c0d68f52fb1')]}
# {'_id': ObjectId('5c9265d768a3ff3428350c45'), 'token': 'наблюдавшихся', 'iniForm': 'наблюдаться', 'POS': 'PRTF', 'freq': 3, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9276ceec882c0d68f52fb1')]}

# %% [markdown]
# Попробуем найти все документы со сложностью равной 6.8 (статья про F-35).

# %%
for l in text_collection.find({'art_info': {'difficulty': '2.1'}}):
    print(l)

# %% [markdown]
# Ничего не найдено, так как такая запись преполагает полное совпадение, то есть поиск поддокумента с единственным полем и этим значением. Если полей будет несколько, роль будет играть даже порядок следования полей в базе!
#
# То, что мы хотели сделать, можно сделать вот так.

# %%
for l in text_collection.find({'art_info.difficulty': '2.1'}):
    print(l)
# Out:
# {'_id': ObjectId('5c92660268a3ff3428350cf2'), 'text_url': 'https://nplus1.ru/news/2015/04/06/gender-and-morality-', 'text_name': 'Психологи рассказали о влиянии пола на этические воззрения', 'art_text': 'Исследователи Кельнского, Техасского и Университета\xa0Уилфрида Лорье обнаружили корреляцию между полом и теми моральными принципами, на основании которых люди подходят к решению этических дилемм.\xa0Статья была опубликована\nв Personality and Social\nPsychology Bulletin.\n\nЭксперимент проводился на базе мета-анализа 40 исследований, в которых принимали\nучастие 6100 участников обоих полов. Участникам задавали 20 вопросов, которые\nпредставляли моральные дилеммы разной сложности. Среди них были вопросы об убийствах,\nпытках, лжи, абортах и экспериментах на животных: например, можно ли\nполицейскому пытать экстремиста-подрывника с целью получения информации о\nзаложенных бомбах? Было бы правильнее убить Адольфа Гитлера, пока он был\nмолодым австрийским художником, чтобы предотвратить Вторую мировую войну и\nспасти миллионы жизней?\n\nЭксперимент был спланирован так, чтобы противопоставлялись два философских подхода к этике. В деонтологии\n(нормативной этике), допустимость действия зависит от моральной нормы,\nвзятой за точку отсчета. Утилитаризм\nже, напротив, настаивает на том, что действие соответствует моральной норме,\nесли из него можно выжать максимальную пользу, всеобщее благо. С точки зрения\nутилитаризма, одно и то же действие моет быть нравственным в одной ситуации, и\nбезнравственным в другой, в зависимости от потенциального результата.\n\nИспользуя специальную статистическую процедуру\xa0удалось определить подсознательную склонность принимать те или иные решения. Оказалось, что женщины более склонны,\nчем мужчины, придерживаться деонтологических принципов (d = 0.57, то есть разница между средними примерно в два раза меньше, чем стандартное отклонение). При этом мужчины и женщины в равной степени руководствуются утилитаризмом.\xa0Из этого авторы делают вывод о том, что у женщин более сильное эмоциональное отторжение к причинению\nвреда, что и объясняет разницу в отношении к деонтологическому и утилитаристскому подходу.\xa0\n\nВлияние пола на этику исследуется не впервые. Исследователи\xa0Университете Квебека недавно попытались установить влияние внутриполовой конкуренции на моральные принципы (например, "Если перед вами стоит выбор - спасти трех\nпредставителей вашего пола или одного представителя противоположного, кого вы\nвыберите?"). Оказалось, что в большинстве случаев мужчины спасут противоположный пол, а женщины - оставят представительниц своего пола.\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_date': '06 Апр. 2015', 'art_time': '12:14', 'difficulty': '2.1', 'author': 'Юлия Минц'}}
# {'_id': ObjectId('5c9277deec882c0d68f5314a'), 'text_name': 'Психологи рассказали о влиянии пола на этические воззрения', 'text_url': 'https://nplus1.ru/news/2015/04/06/gender-and-morality-', 'art_text': 'Исследователи Кельнского, Техасского и Университета\xa0Уилфрида Лорье обнаружили корреляцию между полом и теми моральными принципами, на основании которых люди подходят к решению этических дилемм.\xa0Статья была опубликована\nв Personality and Social\nPsychology Bulletin.\n\nЭксперимент проводился на базе мета-анализа 40 исследований, в которых принимали\nучастие 6100 участников обоих полов. Участникам задавали 20 вопросов, которые\nпредставляли моральные дилеммы разной сложности. Среди них были вопросы об убийствах,\nпытках, лжи, абортах и экспериментах на животных: например, можно ли\nполицейскому пытать экстремиста-подрывника с целью получения информации о\nзаложенных бомбах? Было бы правильнее убить Адольфа Гитлера, пока он был\nмолодым австрийским художником, чтобы предотвратить Вторую мировую войну и\nспасти миллионы жизней?\n\nЭксперимент был спланирован так, чтобы противопоставлялись два философских подхода к этике. В деонтологии\n(нормативной этике), допустимость действия зависит от моральной нормы,\nвзятой за точку отсчета. Утилитаризм\nже, напротив, настаивает на том, что действие соответствует моральной норме,\nесли из него можно выжать максимальную пользу, всеобщее благо. С точки зрения\nутилитаризма, одно и то же действие моет быть нравственным в одной ситуации, и\nбезнравственным в другой, в зависимости от потенциального результата.\n\nИспользуя специальную статистическую процедуру\xa0удалось определить подсознательную склонность принимать те или иные решения. Оказалось, что женщины более склонны,\nчем мужчины, придерживаться деонтологических принципов (d = 0.57, то есть разница между средними примерно в два раза меньше, чем стандартное отклонение). При этом мужчины и женщины в равной степени руководствуются утилитаризмом.\xa0Из этого авторы делают вывод о том, что у женщин более сильное эмоциональное отторжение к причинению\nвреда, что и объясняет разницу в отношении к деонтологическому и утилитаристскому подходу.\xa0\n\nВлияние пола на этику исследуется не впервые. Исследователи\xa0Университете Квебека недавно попытались установить влияние внутриполовой конкуренции на моральные принципы (например, "Если перед вами стоит выбор - спасти трех\nпредставителей вашего пола или одного представителя противоположного, кого вы\nвыберите?"). Оказалось, что в большинстве случаев мужчины спасут противоположный пол, а женщины - оставят представительниц своего пола.\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_time': '12:14', 'author': 'Юлия Минц', 'difficulty': '2.1', 'art_date': '06 Апр. 2015'}}

# %% [markdown]
# Можно выбирать не все поля, а только те, которые нам необходимы.

# %%
for t in text_collection.find(projection=['art_info']):
    print(t)
# Out:
# {'_id': ObjectId('5c92660268a3ff3428350cf2'), 'art_info': {'art_date': '06 Апр. 2015', 'art_time': '12:14', 'difficulty': '2.1', 'author': 'Юлия Минц'}}
# {'_id': ObjectId('5c9266ef68a3ff3428350fae'), 'art_info': {'art_date': '02 Авг. 2016', 'art_time': '09:20', 'difficulty': '3.2', 'author': 'Василий Сычев'}}
# {'_id': ObjectId('5c9267ce68a3ff34283511d4'), 'art_info': {'art_date': '16 Июнь 2016', 'art_time': '15:02', 'difficulty': '3.8', 'author': 'Кристина Уласович'}}
# {'_id': ObjectId('5c92688568a3ff3428351384'), 'art_info': {'art_date': '27 Июнь 2016', 'art_time': '11:17', 'difficulty': '3.9', 'author': 'Кристина Уласович'}}
# {'_id': ObjectId('5c92697668a3ff342835156e'), 'art_info': {'art_date': '27 Июнь 2016', 'art_time': '13:12', 'difficulty': '2.7', 'author': 'Кристина Уласович'}}
# {'_id': ObjectId('5c9269b768a3ff3428351610'), 'art_info': {'art_date': '12 Апр. 2016', 'art_time': '15:26', 'difficulty': '3.3', 'author': 'Кристина Уласович'}}
# {'_id': ObjectId('5c9276ceec882c0d68f52fb1'), 'art_info': {'art_time': '20:09', 'author': 'Владимир Королев', 'difficulty': '2.5', 'art_date': '02 Авг. 2016'}}
# {'_id': ObjectId('5c9277deec882c0d68f5314a'), 'art_info': {'art_time': '12:14', 'author': 'Юлия Минц', 'difficulty': '2.1', 'art_date': '06 Апр. 2015'}}
# {'_id': ObjectId('5c927935ec882c0d68f5326f'), 'art_info': {'art_time': '09:20', 'author': 'Василий Сычев', 'difficulty': '3.2', 'art_date': '02 Авг. 2016'}}

# %% [markdown]
# Для поиска в массивах одного значения можно просто проводить поиск, БД сама будет искать объекты в массиве.
#
# Если мы ищем несколько значений в массиве, необходимо использовать соответствующие предикаты: `$in` для поиска вхождения одного из элементов, `$all` - поиска всех элементов, и т.д.
#
# Обратите внимание, для поиска мы используем не строку, а объект `ObjectId`, импортированный из библиотеки `bson`.
#
# Помимо этого, во втором цикле в поле projection мы передаем не только какие поля надо выводить, но и какие поля выводить не надо. Так, поле \_id, хранящее идентификатор документа, по умолчанию должно выводиться. В примере ниже оно подавляется при помощи `"_id":False`.

# %%
for d in dictionary.find({"docs": ObjectId('5c92660268a3ff3428350cf2')})[:5]:
    print(d)
    
print("-----")
for d in dictionary.find({"docs": {"$all": [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9269b768a3ff3428351610')]}},
                         projection={"_id":False, "token":True, "docs":True}):
    print(d)
# Out:
# {'_id': ObjectId('5c9265d668a3ff3428350c42'), 'token': 'из', 'iniForm': 'из', 'POS': 'PREP', 'freq': 16, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'_id': ObjectId('5c9265d768a3ff3428350c48'), 'token': 'с', 'iniForm': 'с', 'POS': 'PREP', 'freq': 16, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5c927935ec882c0d68f5326f')]}
# {'_id': ObjectId('5c9265da68a3ff3428350c54'), 'token': 'и', 'iniForm': 'и', 'POS': 'CONJ', 'freq': 51, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5c927935ec882c0d68f5326f')]}
# {'_id': ObjectId('5c9265de68a3ff3428350c60'), 'token': 'в', 'iniForm': 'в', 'POS': 'PREP', 'freq': 71, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'_id': ObjectId('5c9265e668a3ff3428350c85'), 'token': 'на', 'iniForm': 'на', 'POS': 'PREP', 'freq': 40, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5c927935ec882c0d68f5326f')]}
# -----
# {'token': 'из', 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'и', 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5c927935ec882c0d68f5326f')]}
# {'token': 'в', 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'на', 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5c927935ec882c0d68f5326f')]}
# {'token': 'В', 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5c927935ec882c0d68f5326f')]}
# {'token': 'или', 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'Исследователи', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'Университета', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'обнаружили', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'которых', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'опубликована', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'например', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'о', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'за', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'то', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'удалось', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'раза', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'не', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'token': 'впервые', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5c927935ec882c0d68f5326f')]}
# {'token': 'трех', 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9277deec882c0d68f5314a')]}

# %%
# А это мы просто смотрим сколько текстов добавили в базу.
# В качестве параметра передается условие, считаются только удовлетворяющие ему документы.
# В данном случае нам нужны все.
print(text_collection.count_documents({}))

# Ищем количество слов с частотой встречаемости от 6 до 9.
print(lemmas.count_documents({"freq":{"$gt": 5, "$lt": 10}}))

# Здесь ищем слова с частотой встречаемости от 6 до 9, 
# просим не выводить идентификатор и отсортировать всё по частоте.
for l in lemmas.find({"freq":{"$gt": 5, "$lt": 10}}, {"_id":False}).sort("freq")[:5]:
    print(l)
print("----")
# Здесь ищем слова с частотой встречаемости от 6 до 9, 
# просим вывести токен и частоту, но не выводить идентификатор и отсортировать всё по частоте.
for l in dictionary.find({"freq":{"$gt": 5}}, {"token": True, "freq":True, "_id":False}).sort("freq")[:5]:
    print(l)
# Out:
# 9
# 54
# {'iniForm': 'самый', 'POS': 'ADJF', 'freq': 6, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1')]}
# {'iniForm': 'момент', 'POS': 'NOUN', 'freq': 6, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c9276ceec882c0d68f52fb1')]}
# {'iniForm': 'взрыв', 'POS': 'NOUN', 'freq': 6, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9276ceec882c0d68f52fb1')]}
# {'iniForm': 'другой', 'POS': 'ADJF', 'freq': 6, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'iniForm': 'между', 'POS': 'PREP', 'freq': 6, 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c9277deec882c0d68f5314a')]}
# ----
# {'token': 'Исследователи', 'freq': 6}
# {'token': 'между', 'freq': 6}
# {'token': 'которых', 'freq': 6}
# {'token': 'были', 'freq': 6}
# {'token': 'можно', 'freq': 6}

# %% [markdown]
# Теперь напишем функцию для того, чтобы класть статью в БД. используем для этого функции:
# - insert_one (insert, insert_many) - добавляет запись (несколько записей) в выбранную коллекцию.
# - find_one_and_update - найти и обновить (аналог update).
#
# В качестве параметра во все функции добавления передается документ (словарь), ключи которого содержат названия полей, а значения - значения этих полей. Значение поля само может являться документом. При поиске часть полей может принимать особые значения, например, `$ne` - не равно, `$size` - смотрим на размер массива, `$inc` - увеличить значение поля на заданную величину и т.д. Более подробно с соответствующими ключами можно ознакомиться <a href="https://metanit.com/nosql/mongodb/" >здесь</a>.

# %%
# Создаем морфоанализатор.
morph=pymorphy2.MorphAnalyzer()

# %%
def putNPlus1ArticleInMongo(art_url):
    # Загружаем текст статьи и другие ее части.
    art = getArticleTextNPlus1(art_url) 

    # Добавляем запись с информацией о статье.
    # inserted_id позволяет сразу получить идентификатор записи, чтобы потом ссылаться на него там, где это необходимо.
    a_text = {"text_url": art_url, "text_name": art.head, "art_text": art.text, 
              "art_info": {"art_date": art.date, "art_time": art.time, 
                           "difficulty": art.diff, "author":art.author}}
    text_id = text_collection.insert_one(a_text).inserted_id
    print(text_id)

    # Выделяем предложения (просто по точке с пробелом или в конце строки!!!).
    sents = re.split("\.\s|\.$", art.text)
    sent_num = 1
    # Загружаем предложения в базу.
    for s in tqdm(sents):
        # Выделяем слова (просто как группы русских букв!!!).
        words = re.findall("([А-Яа-я]+(\-[А-Яа-я]+)?)", s)
        posit = 1
        # Загрузка слов из предложений.
        for w in words:
            wf = morph.parse(w[0])
            # Провели морфологический анализ и теперь добавляем документ с двумя полями: нач. форма и часть речи.
            # Сперва проверяем есть ли там уже такая запись.
            # Смотрим сколько таких слов нашлось. Если ни одного - надо добавлять.
            if lemmas.count_documents({"iniForm": wf[0].normal_form, "POS": wf[0].tag.POS}) == 0:
                lemma_id = lemmas.insert_one({"iniForm": wf[0].normal_form, "POS": wf[0].tag.POS, 
                                              "freq": 1, "docs":[text_id]}).inserted_id
            # А если такое слово уже было, то обновляем частоту встречаемости и в каком документе оно встретиось.
            else:
                inis = lemmas.find({"iniForm": wf[0].normal_form, "POS": wf[0].tag.POS})
                lemma_id = inis[0]["_id"]
                lemmas.find_one_and_update({"_id": lemma_id}, {"$inc": {"freq":1}})
                lemmas.find_one_and_update({"_id": lemma_id}, {"$addToSet": {"docs": text_id}}) 
                # Вот таким образом можно добавлять номер документа столько раз, сколько в нем встретилось слово.
                #lemmas.find_one_and_update({"_id": lemma_id}, {"$push": {"docs": text_id}}) 

            # Повторяем операцию для токенов.
            if dictionary.count_documents({"token":w[0], "iniForm": wf[0].normal_form, "POS": wf[0].tag.POS}) == 0:
                wf_id = dictionary.insert_one({"token":w[0], "iniForm": wf[0].normal_form, "POS": wf[0].tag.POS, "freq": 1, "docs": [text_id]}).inserted_id
            else:
                wrdf = dictionary.find({"token": w[0], "iniForm": wf[0].normal_form, "POS": wf[0].tag.POS})
                wf_id=wrdf[0]["_id"]
                dictionary.find_one_and_update({"_id": wf_id}, {"$inc":  {"freq": 1}}) 
                dictionary.find_one_and_update({"_id": wf_id}, {"$addToSet": {"docs": text_id}}) 
  
            # Добавляем номер предложения, идентификатор словоформы из словаря, позицию слова, из какого оно текста.
            dbsents.insert_one({"sent_id": sent_num, "wordFormId":wf_id, "position": posit, "textId": text_id})
            posit += 1  
        sent_num += 1

# %%
# Добавляем статью  в базу.
#putNPlus1ArticleInMongo("https://nplus1.ru/news/2020/01/20/Exomars-2020-rover-yes")
#putNPlus1ArticleInMongo("https://nplus1.ru/news/2020/01/20/subwavelength-resonators")
#putNPlus1ArticleInMongo("https://nplus1.ru/news/2020/01/20/crew-dragon-first-crewed-flight")
putNPlus1ArticleInMongo("https://nplus1.ru/news/2020/01/18/visual-perception")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2020/01/18/dancing-recognition")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2016/06/27/juno-pictures")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2016/04/12/alignment-of-jets")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2016/06/29/Ultra-Deep-Survey")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2018/03/20/balance")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2018/03/20/abel-prize-2018")
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 5e25c4cf0c009e4fcdd41949
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
#   5%|▍         | 1/22 [00:16<05:53, 16.85s/it]
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
#   9%|▉         | 2/22 [00:29<05:13, 15.67s/it]
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
#  14%|█▎        | 3/22 [01:22<08:28, 26.79s/it]
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
#  18%|█▊        | 4/22 [01:39<07:06, 23.72s/it]
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
#  23%|██▎       | 5/22 [01:56<06:09, 21.76s/it]
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
#  27%|██▋       | 6/22 [02:35<07:10, 26.88s/it]
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
#  32%|███▏      | 7/22 [03:02<06:43, 26.91s/it]
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
#  36%|███▋      | 8/22 [03:34<06:40, 28.60s/it]
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
#  41%|████      | 9/22 [04:03<06:12, 28.65s/it]
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
#  45%|████▌     | 10/22 [04:41<06:18, 31.54s/it]
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
#  50%|█████     | 11/22 [05:37<07:07, 38.85s/it]
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 0
#  55%|█████▍    | 12/22 [05:53<05:18, 31.87s/it]
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
#  59%|█████▉    | 13/22 [07:00<06:21, 42.41s/it]
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
#  64%|██████▎   | 14/22 [07:24<04:57, 37.13s/it]
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
#  68%|██████▊   | 15/22 [07:48<03:51, 33.03s/it]
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
#  73%|███████▎  | 16/22 [08:28<03:31, 35.18s/it]
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
#  77%|███████▋  | 17/22 [08:55<02:43, 32.71s/it]
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
#  82%|████████▏ | 18/22 [09:09<01:47, 26.97s/it]
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
#  86%|████████▋ | 19/22 [09:33<01:18, 26.13s/it]
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
#  91%|█████████ | 20/22 [10:04<00:55, 27.67s/it]
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
# lem count 1
#  95%|█████████▌| 21/22 [12:33<01:04, 64.05s/it]
# lem count 1
# lem count 0
# lem count 0
# lem count 0
# lem count 1
# lem count 1
# lem count 1
# lem count 0
# lem count 1
# lem count 0
# lem count 0
# 100%|██████████| 22/22 [12:43<00:00, 47.95s/it]

# %%
# Вот так можно удалить всё в базе. Если написать условие, то не всё. 
# Экспериментировать не будем, да?
text_collection.delete_many({})
dictionary.delete_many({})
lemmas.delete_many({})
dbsents.delete_many({})
#for l in dbsents.find():
# print(l)

# %%
# Так можно посмотреть все записи, у которых в токене записан список ровно из пяти элементов.
for l in dictionary.find({"docs":{"$size":5}})[:5]:
    print(l)
print("=====")
# Так можно посмотреть все записи, у которых есть поле docs.
for l in lemmas.find({"docs":{"$exists":True}})[:5]:
    print(l)
# Out:
# {'_id': ObjectId('5c9265eb68a3ff3428350c9d'), 'token': 'стало', 'iniForm': 'стать', 'POS': 'VERB', 'freq': 7, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c927935ec882c0d68f5326f'), ObjectId('5e25c4cf0c009e4fcdd41949')]}
# {'_id': ObjectId('5c9265ee68a3ff3428350ca9'), 'token': 'был', 'iniForm': 'быть', 'POS': 'VERB', 'freq': 7, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'_id': ObjectId('5c92660968a3ff3428350d0d'), 'token': 'между', 'iniForm': 'между', 'POS': 'PREP', 'freq': 7, 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9267ce68a3ff34283511d4'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5e25c4cf0c009e4fcdd41949')]}
# {'_id': ObjectId('5c92661468a3ff3428350d38'), 'token': 'была', 'iniForm': 'быть', 'POS': 'VERB', 'freq': 7, 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5e25c0ae0c009e4fcdd412ab')]}
# {'_id': ObjectId('5c92661568a3ff3428350d3b'), 'token': 'опубликована', 'iniForm': 'опубликовать', 'POS': 'PRTS', 'freq': 5, 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5e25c1850c009e4fcdd41494')]}
# =====
# {'_id': ObjectId('5c9265d468a3ff3428350c38'), 'iniForm': 'сверхновый', 'POS': 'ADJF', 'freq': 7, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9276ceec882c0d68f52fb1')]}
# {'_id': ObjectId('5c9265d468a3ff3428350c3b'), 'iniForm': 'самый', 'POS': 'ADJF', 'freq': 7, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5e25c4cf0c009e4fcdd41949')]}
# {'_id': ObjectId('5c9265d568a3ff3428350c3e'), 'iniForm': 'близкий', 'POS': 'ADJF', 'freq': 3, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9276ceec882c0d68f52fb1')]}
# {'_id': ObjectId('5c9265d668a3ff3428350c41'), 'iniForm': 'из', 'POS': 'PREP', 'freq': 28, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5e25c1850c009e4fcdd41494'), ObjectId('5e25c2aa0c009e4fcdd41701'), ObjectId('5e25c4cf0c009e4fcdd41949')]}
# {'_id': ObjectId('5c9265d668a3ff3428350c44'), 'iniForm': 'наблюдаться', 'POS': 'PRTF', 'freq': 3, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c9276ceec882c0d68f52fb1')]}

# %% [markdown]
# При помощи ключевого слова `$regex' можно искать в базе строки, отвечающие регулярным выражениям.

# %%
# iniForm _какое_ описывается_регуляркой _какой_ ^и.+
for d in lemmas.find({'iniForm':{'$regex':'^и.+'}})[:5]:
    print(d)
    
for d in dictionary.find({'token':{'$regex':'^[А-Я].+'}})[:5]:
    print(d)
# Out:
# {'_id': ObjectId('5e25c7cb0c009e4fcdd41d83'), 'iniForm': 'ивтушок', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('5e25c4cf0c009e4fcdd41949')]}
# {'_id': ObjectId('5e25c4ff0c009e4fcdd41999'), 'iniForm': 'играть', 'POS': 'VERB', 'freq': 2, 'docs': [ObjectId('5e25c4cf0c009e4fcdd41949')]}
# {'_id': ObjectId('5e25c3a40c009e4fcdd418dd'), 'iniForm': 'идея', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('5e25c2aa0c009e4fcdd41701')]}
# {'_id': ObjectId('5c9265d668a3ff3428350c41'), 'iniForm': 'из', 'POS': 'PREP', 'freq': 28, 'docs': [ObjectId('5c9264f168a3ff3428350b72'), ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9266ef68a3ff3428350fae'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c92697668a3ff342835156e'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5e25c1850c009e4fcdd41494'), ObjectId('5e25c2aa0c009e4fcdd41701'), ObjectId('5e25c4cf0c009e4fcdd41949')]}
# {'_id': ObjectId('5c9268c868a3ff3428351409'), 'iniForm': 'из-за', 'POS': 'PREP', 'freq': 1, 'docs': [ObjectId('5c92688568a3ff3428351384')]}
# {'_id': ObjectId('5c927717ec882c0d68f53039'), 'iniForm': 'австралия', 'freq': 2, 'token': 'Австралии', 'POS': 'NOUN', 'docs': [ObjectId('5c9276ceec882c0d68f52fb1'), ObjectId('5e25c1850c009e4fcdd41494')]}
# {'_id': ObjectId('5e25c22d0c009e4fcdd41609'), 'token': 'Австралийского', 'iniForm': 'австралийский', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('5e25c1850c009e4fcdd41494')]}
# {'_id': ObjectId('5c92663d68a3ff3428350dc6'), 'token': 'Адольфа', 'iniForm': 'адольф', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'_id': ObjectId('5e25c1840c009e4fcdd4148f'), 'token': 'Александр', 'iniForm': 'александр', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('5e25c0ae0c009e4fcdd412ab')]}
# {'_id': ObjectId('5e25c4d00c009e4fcdd4194a'), 'token': 'Американские', 'iniForm': 'американский', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('5e25c4cf0c009e4fcdd41949')]}

# %% [markdown]
# Ключевое слово `$or` и другие операторы позволяют применять логические свзки помимо логического И.

# %%
# _или_по_списку_условий_ [token _какой_ описывается_регуляркой _какой_ ^И.+, 
#                          token _какой_ описывается_регуляркой _какой_ .+ъ.+]
for d in dictionary.find({'$or':[{'token':{'$regex':'^И.+'}}, {'token':{'$regex':'.+ъ.+'}}]})[:5]:
    print(d)
# Out:
# {'_id': ObjectId('5e25c22d0c009e4fcdd41606'), 'token': 'ИТМО', 'iniForm': 'итмый', 'POS': 'ADJS', 'freq': 1, 'docs': [ObjectId('5e25c1850c009e4fcdd41494')]}
# {'_id': ObjectId('5e25c7cb0c009e4fcdd41d84'), 'token': 'Ивтушок', 'iniForm': 'ивтушок', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('5e25c4cf0c009e4fcdd41949')]}
# {'_id': ObjectId('5c9266a868a3ff3428350eff'), 'token': 'Из', 'iniForm': 'из', 'POS': 'PREP', 'freq': 3, 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5e25c1850c009e4fcdd41494')], 'found': 'true'}
# {'_id': ObjectId('5e25c3830c009e4fcdd4189a'), 'token': 'Изначально', 'iniForm': 'изначально', 'POS': 'ADVB', 'freq': 1, 'docs': [ObjectId('5e25c2aa0c009e4fcdd41701')]}
# {'_id': ObjectId('5e25c2b60c009e4fcdd41723'), 'token': 'Илон', 'iniForm': 'илона', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('5e25c2aa0c009e4fcdd41701')]}

# %% [markdown]
# Обратите внимание, что при обновлении заменяетя весь докуент целиком. Чтобы избежать этого следует использовать ключевое слово `$set`, которое показывает, что обновляется значение только одного поля.

# %%
# Просто посмотрим на документы
for d in dictionary.find({'token':{'$regex':'^И.+'}}):
    print(d)
# Out:
# {'_id': ObjectId('5e25c22d0c009e4fcdd41606'), 'token': 'ИТМО', 'iniForm': 'итмый', 'POS': 'ADJS', 'freq': 1, 'docs': [ObjectId('5e25c1850c009e4fcdd41494')]}
# {'_id': ObjectId('5e25c7cb0c009e4fcdd41d84'), 'token': 'Ивтушок', 'iniForm': 'ивтушок', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('5e25c4cf0c009e4fcdd41949')]}
# {'_id': ObjectId('5c9266a868a3ff3428350eff'), 'token': 'Из', 'iniForm': 'из', 'POS': 'PREP', 'freq': 3, 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5e25c1850c009e4fcdd41494')], 'found': 'true'}
# {'_id': ObjectId('5e25c3830c009e4fcdd4189a'), 'token': 'Изначально', 'iniForm': 'изначально', 'POS': 'ADVB', 'freq': 1, 'docs': [ObjectId('5e25c2aa0c009e4fcdd41701')]}
# {'_id': ObjectId('5e25c2b60c009e4fcdd41723'), 'token': 'Илон', 'iniForm': 'илона', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('5e25c2aa0c009e4fcdd41701')]}
# {'_id': ObjectId('5e25c27a0c009e4fcdd416a1'), 'token': 'Интенсивные', 'iniForm': 'интенсивный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('5e25c1850c009e4fcdd41494')]}
# {'_id': ObjectId('5e25c4ee0c009e4fcdd41980'), 'token': 'Использование', 'iniForm': 'использование', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('5e25c4cf0c009e4fcdd41949')]}
# {'_id': ObjectId('5c92668168a3ff3428350e90'), 'token': 'Используя', 'iniForm': 'использовать', 'POS': 'GRND', 'freq': 2, 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'_id': ObjectId('5c9276feec882c0d68f53009'), 'iniForm': 'исследование', 'freq': 1, 'token': 'Исследование', 'POS': 'NOUN', 'docs': [ObjectId('5c9276ceec882c0d68f52fb1')]}
# {'_id': ObjectId('5c92660368a3ff3428350cf4'), 'token': 'Исследователи', 'iniForm': 'исследователь', 'POS': 'NOUN', 'freq': 6, 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c92688568a3ff3428351384'), ObjectId('5c9269b768a3ff3428351610'), ObjectId('5c9277deec882c0d68f5314a')]}
# {'_id': ObjectId('5c92689668a3ff34283513a8'), 'token': 'Их', 'iniForm': 'они', 'POS': 'NPRO', 'freq': 2, 'docs': [ObjectId('5c92688568a3ff3428351384'), ObjectId('5e25c1850c009e4fcdd41494')]}

# %%
# А теперь найдем первое попавшееся слово, начинающееся с заглавное И и добавим ему новое поле found
dictionary.find_one_and_update({'token':{'$regex':'^И.+'}}, {'$set': {'found':'true'}})
# Out:
# {'POS': 'ADJS',
#  '_id': ObjectId('5e25c22d0c009e4fcdd41606'),
#  'docs': [ObjectId('5e25c1850c009e4fcdd41494')],
#  'freq': 1,
#  'iniForm': 'итмый',
#  'token': 'ИТМО'}

# %%
# Попробуем найти все документы с полем found.
for d in dictionary.find({'found':{"$exists":True}}):
    print(d)
# Out:
# {'_id': ObjectId('5c9266a868a3ff3428350eff'), 'token': 'Из', 'iniForm': 'из', 'POS': 'PREP', 'freq': 3, 'docs': [ObjectId('5c92660268a3ff3428350cf2'), ObjectId('5c9277deec882c0d68f5314a'), ObjectId('5e25c1850c009e4fcdd41494')], 'found': 'true'}
# {'_id': ObjectId('5e25c22d0c009e4fcdd41606'), 'token': 'ИТМО', 'iniForm': 'итмый', 'POS': 'ADJS', 'freq': 1, 'docs': [ObjectId('5e25c1850c009e4fcdd41494')], 'found': 'true'}

# %% [markdown]
# ## Важное замечание
#
# Вся структура нашей базы данных отдает реляционностью. Никто не мешал нам сделать документ, вложенный в словарь начальных форм и хранить в нем все формы данного слова. Тогда если что, не надо будет делать запросы, в которых надо делать пересечение двух коллекций.
