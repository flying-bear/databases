# %% [markdown]
# ElasticSearch - это документарная база данных с возможностью полнотекстовго и географического поиска.
#
# Попробуем решить с ее помощью знакомую задачу - выкачать NPlus1 и положить статьи в базу данных.
#
# База данных [ставится](https://www.elastic.co/guide/en/elasticsearch/reference/current/install-elasticsearch.html) довольно просто, дальше к ней можно обращаться просто по локальному адресу, порт 9200: https://127.0.0.1:9200/ . На все запросы база данных будет присылать JSON-документ. То есть при желании с ней можно работать при помощи библиотеки `requests`. Вместо этого поставим библиотеку `elasticsearch` и будем работать через нее.

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import datetime
from tqdm import tqdm

# Импортируем библиотеку для БД.
from elasticsearch import Elasticsearch

# %% [markdown]
# К базе данных нужно обращаться при помощи класса `Elasticsearch`.

# %%
# Подключаемся к базе данных.
es=Elasticsearch()

# %%
es
# Out:
# <Elasticsearch([{}])>

# %% [markdown]
# Создадим класс `NPlus1Article`, который будет хранить информацию по статье и преобразовывать ее к словарю или JSON. Используем старые функции, которые выгружают статьи за весь день и статьи за заданный период.

# %%
delcom=re.compile("<!--.+-->", re.S)

# Класс, хранящий информацию о статье.
class NPlus1Article:
    def __init__(self):
        self.time=""
        self.date=""
        self.rubr=""
        self.diff=""
        self.author=""
        self.head=""
        self.text=""
        
    # Конвертация в JSON.
    def toJSON(self):
        res='{"date":"'+self.date+'", "time":"'+self.time+'", "rubrics":"'+self.rubr+'", "difficulty":"'
        res+=self.diff+'", "title":"'+self.head+'", "author":"'+self.author+'","text":"'
        res+=self.text.replace('"', '\\"')+'"}'
        return res

    # Конвертация в словарь.
    def toDict(self):
        res={"date":self.date, "time":self.time, "rubrics":self.rubr, "difficulty":self.diff,\
             "title":self.head, "author":self.author,"text":self.text.replace('"', '\\"')}
        return res
    
def getArticleTextNPlus1(adr):
    r = requests.get(adr)
    #print(r.text)
    art = NPlus1Article()
    tables = re.split("</div>",re.split('="tables"', r.text)[1])[0]
    t1 = re.split("</time>", re.split("<time", tables)[1])[0]
    art.time = re.split("</span>", re.split("<span>", t1)[1])[0]
    art.date = re.split("</span>", re.split("<span>", t1)[2])[0]
    art.rubr = re.findall("<a data-rubric.+?>(.+?)</a>", r.text)[0]
    art.diff = re.split("</span>", re.split('"difficult-value">', tables)[1])[0]
    art.head = re.split("</h1>",re.split('<h1>', r.text)[1])[0]
    art.author = re.split('" />',re.split('<meta name="author" content="', r.text)[1])[0]
    art.text = re.split("</div>", re.split("</figure>", re.split('</article>',re.split('<article', r.text)[1])[0])[1])[1]    

    beaux_text = BeautifulSoup(art.text, "html.parser")
    art.text = delcom.sub("", beaux_text.get_text() )
    art.text = art.text.replace('\xa0', ' ')

    # print(art.n_time, art.n_date, art.n_rubr, art.n_diff)
    # print(art.n_head)
    # print(art.n_author)
    # print(art.n_text)
    #return [n_time, n_date, n_rubr, n_diff, n_author, n_head, n_text]
    return art

def getDayArticles(adr):
    r = requests.get(adr)
    titles = BeautifulSoup(r.text, "html.parser")("article")
    #print(titles)
    addrs = ["https://nplus1.ru/"+a("a")[0]["href"] for a in titles]
    #print(addrs)
    articles = []
    for adr in addrs:
        articles.append(getArticleTextNPlus1(adr))
    return articles

# %% [markdown]
# Загрузим статьи за несколько дней.

# %%
#arts=getDayArticles("https://nplus1.ru/news/2019/02/01")
arts=getDayArticles("https://nplus1.ru/news/2017/10/16/")
#arts=getDayArticles("https://nplus1.ru/news/2016/08/04/")

# %%
# !pip install --upgrade bs4
# Out:
# Requirement already up-to-date: bs4 in c:\users\lenovo\appdata\local\programs\python\python36\lib\site-packages (0.0.1)
# Requirement already satisfied, skipping upgrade: beautifulsoup4 in c:\users\lenovo\appdata\local\programs\python\python36\lib\site-packages (from bs4) (4.8.1)
# Requirement already satisfied, skipping upgrade: soupsieve>=1.2 in c:\users\lenovo\appdata\local\programs\python\python36\lib\site-packages (from beautifulsoup4->bs4) (1.9.4)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# Вся информация хранится в так называемых индексах (аналог базы данных).
#
# Создадим индекс при помощи `indices.create(index=название_индекса)`

# %%
es.indices.create(index="nplus1")
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'nplus1'}

# %% [markdown]
# Для индекса можно задать тип документа, который будет в нем храниться. Если тип не будет задан, БД сама создаст его при первой загрузке документа (не всегда так, как этого хотелось бы нам, поэтому лучше тип задавать явно).
#
# Описание типа (маппинг) ведется в виде JSON или словаря. Оно должно содержать в себе название типа (в нашем случае это "article") и описание полей. Описание полей дается после ключевого слова "properties". Для каждого поля задается его название за которым следует описание поля: тип, формат, анализатор (язык), другие параметры.
#
# Маппинг для существующего индекса создается при помощи `indices.put_mapping`, в [который](https://elasticsearch-py.readthedocs.io/en/master/api.html#elasticsearch.client.IndicesClient.put_mapping) передается названия индекса и типа. Можно передать маппинг сразу в функцию создания индекса.

# %%
mapit={"article":{"properties":{"author":{"type":"text"},
                                "date":{"type":"text"},
                                "time":{"type":"date", "format":"HH:mm"},
                                "difficulty":{"type":"double"},
                                "rubrics":{"type":"text", "analyzer":"russian"},
                                "text":{"type":"text", "analyzer":"russian"},
                                "title":{"type":"text", "analyzer":"russian"}}}}

es.indices.put_mapping(index="nplus1", doc_type='article', body=mapit, include_type_name=True)
# Out:
# {'acknowledged': True}

# %% [markdown]
# При желании индекс можно [удалить](https://elasticsearch-py.readthedocs.io/en/master/api.html#elasticsearch.client.IndicesClient.delete).

# %%
es.indices.delete("nplus1")
# Out:
# {'acknowledged': True}

# %% [markdown]
# Можно получить список индексов для текущей базы.

# %%
es.indices.get_alias("*")
# Out:
# {'nplus1': {'aliases': {}}}

# %% [markdown]
# Можно получить маппинг для интересующего нас индекса.

# %%
es.indices.get_mapping(index="nplus1", doc_type='article', include_type_name=True)
# Out:
# {'nplus1': {'mappings': {'article': {'properties': {'author': {'type': 'text'},
#      'date': {'type': 'text'},
#      'difficulty': {'type': 'double'},
#      'rubrics': {'type': 'text', 'analyzer': 'russian'},
#      'text': {'type': 'text', 'analyzer': 'russian'},
#      'time': {'type': 'date', 'format': 'HH:mm'},
#      'title': {'type': 'text', 'analyzer': 'russian'}}}}}}

# %% [markdown]
# Загрузка документов в базу ведется при помощи функции `index`. Тем самым БД и библиотека подчеркивают, что для них строится полнотекстовый индекс для быстрого поиска. [В функцию](https://elasticsearch-py.readthedocs.io/en/master/api.html#elasticsearch.Elasticsearch.index) передаются название индекса и типа документа. Также можно передать идентификатор документа и другие параметры.

# %%
# %%time

for art in tqdm(arts):
    es.index(index="nplus1", doc_type='article', body=art.toDict())
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 69.39it/s]
# Wall time: 273 ms

# %% [markdown]
# Получить документ по его идентификатору можно при помощи [функции](https://elasticsearch-py.readthedocs.io/en/master/api.html#elasticsearch.Elasticsearch.get) `get`.
#
# Но в дальнейшем мы будем пользоваться [функцией](https://elasticsearch-py.readthedocs.io/en/master/api.html#elasticsearch.Elasticsearch.search) `search`, которая позволяет проводить любой поиск, фильтрацию и аггрегацию информации. Для поиска надо передать название индекса и запрос в виде JSON или словаря.
#
# В простейшем случае запрос содержит в себе поле `query`, включающее в себе описание документов, которые мы хотим найти. Также в запрос могут включаться другие параметры: количество выводимых документов, фильтры, аггрегация и др.
#
# В запросе ниже мы используем `match_all`, то есть просьбу вывести все документы. По умолчанию выводятся 10 документов.
#
# Результат содержит в себе несколько полей, `["hits"]["hits"]` содержит найденные документы.

# %%
#es.get(index="nplus1", doc_type='article', id=1)
res = es.search(index="nplus1", body={"query": {"match_all": {}}})
res["hits"]["hits"]
# Out:
# [{'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'dAW2FHABiLWAMI7vjS0T',
#   '_score': 1.0,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '18:33',
#    'rubrics': 'Медицина',
#    'difficulty': '2.1',
#    'title': 'В донорской крови нашли африканский птичий вирус',
#    'author': 'Дарья Спасская',
#    'text': '\n\n\nАфриканский вирус Усуту, который с начала 2000-х годов вызвал\nв Европе несколько эпидемий среди птиц, встречается у людей чаще, чем\nожидалось. В частности, вирус был обнаружен в семи образцах донорской крови в\nавстрийском донорском центре. Об этом сообщает европейский эпидемиологический\nжурнал Eurosurveillance, а\nо распространении вируса среди птиц на территории Австрии и Венгрии авторы\nрассказали в журнале Emerging Microbes & Infections.\nВирус Усуту\nотносится к группе флавивирусов, так же как вирус энцефалита, лихорадки\nЗападного Нила, денге и вирус Зика. Как и многие представители этой группы,\nпереносится вирус Усуту комарами. Он был впервые описан на территории Африки в\n1959 году, а в 2001 году был зарегистрирован на территории Австрии, где вызвал\nэпидемию энцефалита среди дроздов. С 2003 по 2006 годы в Австрии также нередко\nвстречались случаи заражения диких птиц, однако потом болезнь пошла на спад,\nпо-видимому благодаря выработке иммунитета против вируса. С тех пор и по сей\nдень вспышки вирусной инфекции среди перелетных птиц регистрировали в разных\nстранах Европы, в том числе в Италии, Франции, Германии и других. \nОфициально случаи заражения\nвирусом Усуту людей были подтверждены лишь несколько раз — дважды в Африке, у\nпациентов с лихорадкой, а после в Италии в 2009 году. Два итальянских пациента\nс иммунодефицитом в результате заражения вирусом заболели энцефалитом. Однако,\nисследования, проведенные во время птичьих эпидемий, показали, что антитела\nпротив вируса встречаются у людей не так уж редко. Это означает, что люди регулярно\nзаражаются вирусом, но в подавляющем большинстве случаев инфекция проходит\nбессимптомно. \n В 2014 году австрийский Красный крест, который\nзанимается сбором донорской крови, начал тестировать поступающий к ним материал\nна наличие вируса лихорадки Западного Нила. Летом 2017 года в донорском центре\nбыло обнаружено семь образцов зараженной крови. Дальнейшая проверка не\nподтвердила принадлежность найденной вирусной РНК к искомому виду вируса, зато\nпрояснила, что образцы заражены вирусом Усуту. Как оказалось, все доноры не\nпроявляли никаких клинических симптомов. В тропические страны они не выезжали,\nто есть заразились вирусом на территории Австрии. \nКонечно, факт\nобнаружения неопасного вируса в донорской крови это еще не повод бить тревогу и\nобъявлять эпидемию, однако авторы статьи настаивают, что проверка образцов, а\nвозможно и пациентов, на наличие вируса Усуту, должна стать рутинной процедурой.\nНесмотря на то, что вирус неопасен для здоровых людей, у людей с отягощающими\nфакторами, такими как возраст и наличие других заболеваний, инфекция может\nпривести к развитию неврологических симптомов. К тому же вирусы быстро\nмутируют, а рутинный мониторинг поможет держать ситуацию под контролем и не\nдопустить развития эпидемии в случае появления более опасной формы вируса. Именно\nтак началась эпидемия лихорадки Зика — мы рассказывали, что способность\nвируса Зика поражать клетки-предшественницы нейронов резко повысилась после\nвозникновения единственной мутации в его геноме. \nДарья Спасская\n \n \n\n\n'}},
#  {'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'dQW2FHABiLWAMI7vjS1m',
#   '_score': 1.0,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '17:50',
#    'rubrics': 'IT',
#    'difficulty': '2.8',
#    'title': 'В протоколе Wi-Fi WPA2 обнаружили критические уязвимости',
#    'author': 'Григорий Копиев',
#    'text': '\n\n\nВ протоколе WPA2, используемом для защиты сетей Wi-Fi, обнаружено несколько критических уязвимостей. Эксплуатация этих уязвимостей позволяет злоумышленникам «подслушивать» трафик в зашифрованных сетях или даже изменять его. Хотя бы части из этих уязвимостей подвержены Windows, macOS, Linux, Android, iOS и другие операционные системы, а также аппаратное обеспечение. Описание атак доступно на специальном сайте, а полностью исследование будет представлено 1 ноября 2017 года на конференции CSS.\nНа данный момент основным протоколом защиты сетей Wi-Fi является WPA2. Его поддержка является обязательной для всех сертифицированных Wi-Fi устройств. Он позволяет предоставлять доступ к сети по паролю, а шифрование трафика в таких сетях происходит с помощью уникального для каждого клиента ключа.\nАтака исследователей направлена на четырехстороннее рукопожатие в алгоритме WPA2. Этот механизм используется для аутентификации каждый раз, когда клиент подключается к защищенной сети. Во время рукопожатия точка доступа и клиент формируют ключ, который затем используется для шифрования и безопасной передачи трафика. Исследователи нашли способ вмешаться в этот механизм таким образом, что жертва будет постоянно использовать один и тот же параметр nonce, предназначенный исключительно для одноразового использования. Это в корне подрывает безопасность протокола и позволяет злоумышленнику получать доступ к пакетам, передаваемым по сети.\n\nИсследователи опубликовали список из десяти уязвимостей. Тем или иным вариантам атак оказались подвержены Android, Linux, macOS, iOS, Windows и OpenBSD, а также аппаратное обеспечение MediaTek, Linksys и других крупных производителей. Наибольшую опасность эти атаки представляют для Linux и Android версии 6.0 и выше. В зависимости от конкретной реализации протокола на той или иной платформе злоумышленник, использующий эти уязвимости, может как читать трафик сети, так и вмешиваться в него, например, внедряя вредоносное программное обеспечение в сайты, просматриваемые пользователем.\nСпециалисты заверили, что для устранения уязвимостей не потребуется вводить новый протокол шифрования, достаточно лишь патчей безопасности. Причем, как отмечают исследователи, такие патчи могут быть обратно совместимыми, то есть даже если уязвимости будут исправлены только у клиента или только у точки доступа, они все равно смогут общаться между собой. По словам исследователей, они еще летом 2017 года контактировали с Координационным центром CERT для того, чтобы совместно оповестить крупные компании до обнародования информации об уязвимостях.\nНедавно критические уязвимости были обнаружены и в другом популярном протоколе связи — Bluetooth. Специалисты, обнаружившие эти уязвимости, заявили, что потенциально им подвержено более восьми миллиардов устройств, в том числе работающих под управлением Windows, Android, iOS и других популярных операционных систем. Для их эксплуатации злоумышленникам даже не нужно физически взаимодействовать с устройством жертвы, достаточно лишь активного Bluetooth-соединения на устройстве жертвы. Многие крупные производители уже выпустили обновления безопасности для своих операционных систем или устройств.\nГригорий Копиев\n'}},
#  {'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'dgW2FHABiLWAMI7vjS11',
#   '_score': 1.0,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '17:29',
#    'rubrics': 'Астрономия',
#    'difficulty': '4.1',
#    'title': 'Вертолеты помогли описать завихрения в протопланетных дисках',
#    'author': 'Дмитрий Трунин',
#    'text': '\n\n\nАстрофизики из Йельского университета адаптировали алгоритм инженеров, изучавших взаимодействие лопастей вертолета с создаваемыми ими завихрениями воздуха, для описания процессов в протопланетных и аккреционных дисках. Это позволило учесть теорему Кельвина о циркуляции и получить более точные картины процессов. Статья опубликована в журнале The Astrophysical Journal. \nВ процессе формирования протопланетного или аккреционного диска большую роль играют неламинарные течения, в которых формируются вихри и другие долгоживущие структуры. Также такие особенности наблюдаются в атмосферах планет (например, большое красное пятно на Юпитере). Следовательно, численное моделирование таких дисков должно учитывать сильные нелинейности модели.\nИз-за нелинейностей в процессе численного моделирования вычислительные ошибки могут быстро накапливаться. Поэтому хорошие алгоритмы должны быть разработаны таким образом, чтобы в ходе вычислений не нарушались некоторые важные для исследуемого явления законы сохранения. Обычно требуют выполнения законов сохранения энергии и импульса, а также уравнения непрерывности. Однако в протопланетном диске выполняется еще один закон, который все разработанные методы численного моделирования не учитывают, — закон сохранения зави́хренности (теорема Кельвина о циркуляции). В новой работе астрофизики обошли эту проблему.\nДля этого они воспользовались наработками инженеров, изучавших взаимодействие лопастей вертолета с возникающими завихрениями воздуха. В этой задаче также важно следить за сохранением завихренности, чтобы спроектировать более эффективную геометрию винта. Разработанный инженерами алгоритм RBV2 основывается на полулагранжевом методе (semi-Lagrangian scheme) и разложении Гельмгольца-Ходжа (Helmholtz-Hodge decomposition) и отлично описывает случай медленно смещающихся вихрей, хотя и является методом всего второго порядка точности. Астрофизики применили его к моделированию протопланетных дисков практически без изменений.\n\n\n\n\n\n\n'}},
#  {'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'dwW2FHABiLWAMI7vjS1_',
#   '_score': 1.0,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '17:00',
#    'rubrics': 'Астрономия',
#    'difficulty': '5.2',
#    'title': 'Астрономы впервые услышали гравитационные волны от слияния нейтронных звезд',
#    'author': 'Александр Войтюк',
#    'text': '\n\n\nУченые впервые в истории зафиксировали гравитационные волны от слияния двух нейтронных звезд — сверхплотных объектов массой с наше Солнце и размером с Москву. Возникшие затем гамма-всплеск и вспышку килоновой наблюдали около 70 наземных и космических обсерваторий — они смогли увидеть предсказанный теоретиками процесс синтеза тяжелых элементов, в том числе золота и платины, и подтвердить правоту гипотез о природе загадочных коротких гамма-всплесков, сообщают пресс-служба коллаборации LIGO/Virgo, Европейской Южной обсерватории и обсерватории Лос-Кумбрес. Результаты наблюдений могут пролить свет на загадку строения нейтронных звезд и образование тяжелых элементов во Вселенной.\nУтром 17 августа 2017 года (в 8:41 по времени Восточного побережья США, когда в Москве было 15:41) автоматические системы на одном из двух детекторов гравитационно-волновой обсерватории LIGO зарегистрировали приход гравитационной волны из космоса. Сигнал получил обозначение GW170817, это был уже пятый случай фиксации гравитационных волн с 2015 года, с момента, когда они были впервые зарегистрированы. Всего за три дня до этого обсерватория LIGO впервые «услышала» гравитационную волну вместе с европейским проектом Virgo.\nОднако в этот раз уже через две секунды после гравитационного события космический телескоп Fermi зафиксировал вспышку гамма-излучения на южном небе. Почти в этот же момент вспышку увидела европейско-российская космическая обсерватория INTEGRAL.\nАвтоматические системы анализа данных обсерватории LIGO пришли к выводу, что случайное совпадение этих двух событий крайне маловероятно. В ходе поиска дополнительной информации было обнаружено, что гравитационную волну увидел и второй детектор LIGO, но не зафиксировала европейская гравитационная обсерватория Virgo. Астрономы всего мира были подняты «по тревоге» — охоту на источник гравитационных волн и гамма-всплеска начали множество обсерваторий, в том числе Европейская Южная обсерватория и космический телескоп Hubble.\n\n\n\n\n\n\n'}},
#  {'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'eAW2FHABiLWAMI7vjS2N',
#   '_score': 1.0,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '16:22',
#    'rubrics': 'Роботы и дроны',
#    'difficulty': '3.1',
#    'title': 'Японцы представили сельскохозяйственный дрон',
#    'author': 'Василий Сычев',
#    'text': '\n\n\nЯпонская компания Yamaha представила сельскохозяйственный дрон YMR-01, который можно использовать для распыления различных химикатов над полями. Как пишет Aviation Week, продажи нового беспилотного летательного аппарата начнутся в 2018 году.В сельскохозяйственной отрасли Yamaha известна в качестве производителя дистанционно управляемых вертолетов Rmax и Fazer. Это крупные машины длиной 3,7 и 2,6 метра соответственно. Они предназначены для обработки больших по площади полей. В настоящее время в сельском хозяйстве используются около 2,5 тысячи таких машин.YMR-01 представляет собой существенно более дешевую альтернативу дистанционно управляемым вертолетам. Один такой аппарат сможет распылять химикаты над полем площадью до 10,1 тысячи квадратных метров. Беспилотник получил распыляющие системы компании Yamabiko, которая и будет продавать YMR-01 через свою дилерскую сеть.Новый дрон выполнен по схеме гексакоптера. Передние и задние два его луча оснащены электромоторами с верхним расположением воздушных винтов. Боковые два луча имеют электромоторы с двумя воздушными соосными винтами, один из которых расположен снизу, а второй — сверху. В полете такие винты, по оценке Yamaha, создают равномерный воздушный поток.Соосно боковым воздушным винтам расположены и форсунки распылителей химикатов. В Yamaha утверждают, что такое расположение распылителей позволяет добиться более равномерного осаждения химикатов на поля. Другие подробности о проекте не уточняются.В конце 2015 года собственный сельскохозяйственный дрон представила китайская компания DJI. Октокоптер Agras MG-1 предназначен для обработки выращиваемых культур пестицидами. На складывающихся плечах беспилотника смонтирована система трубок и разбрызгивающих форсунок, а под корпусом находится емкость вместимостью десять литров. За час MG-1 может обработать участок площадью в три-четыре гектара.Во время распыления дрон самостоятельно регулирует количество выбрасываемых пестицидов в зависимости от скорости передвижения. Также при необходимости вернуться MG-1 запоминает точку, на которой он остановился, и продолжает работу с нее.Василий Сычёв\n'}},
#  {'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'eQW2FHABiLWAMI7vjS2Y',
#   '_score': 1.0,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '16:02',
#    'rubrics': 'Космонавтика',
#    'difficulty': '1.7',
#    'title': 'Китайская орбитальная станция «Тяньгун-1» упадет на Землю в конце года',
#    'author': 'Кристина Уласович',
#    'text': '\n\n\nПервая китайская орбитальная космическая станция «Тяньгун-1» упадет на поверхность Земли в конце 2017 — начале 2018 года. Об этом сообщает The Guardian.\nКосмический аппарат «Тяньгун-1», также именуемый целевым модулем, стал первой не советской и не американской орбитальной станцией. Он представляет собой прототип более крупной станции, которая начнет работу в начале 2020-х годов. Корабль, предназначенный для отработки технологий сближения и стыковки космических аппаратов, был запущен в космос сентябре 2011 года. Станция весит 8,5 тонн и в длину достигает 10,4 метров. Корабль использовался как для научных экспериментов, например для съемки земной поверхности, так и для пилотируемых миссий. Модуль способен обеспечивать жизнедеятельность 3 космонавтов в течение 20 суток. В 2012 году его посетила первая в Китае женщина-космонавт Лю Ян. \nВ 2016 году власти Китая сообщили, что они потеряли возможность корректировать орбиту «Тяньгун-1» и ожидают, что станция упадет на Землю в период с октября 2017 года по апрель 2018 года. Однако совсем недавно стало известно, что корабль вошел в более плотные слои атмосферы нашей планеты и скорость его снижения увеличилась. Согласно новым прогнозам, «Тяньгун-1» упадет на поверхность в ближайшие несколько месяцев.\nБольшая часть космического аппарата должна сгореть в атмосфере Земли, однако эксперты отмечают, что некоторые куски весом до 100 килограмм могут уцелеть. Шансы на то, что они попадут в населенный пункт, малы, однако «Комитет по использованию космического пространства в мирных целях» (COPUOS) будет следить за обломками станции и информировать членов ООН о ходе развития событий.В апреле 2017 года на орбиту вышел первый китайский космический грузовик — «Тяньчжоу-1». Ранее китайское национальное космическое управление и Управление ООН по вопросам космического пространства (UNOOSA) заключили соглашение, согласно которому Китай предоставит возможность странам-участницам ООН использовать свою будущую космическую станцию — ее запуск намечен на 2022 год.\nКристина Уласович\n'}},
#  {'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'egW2FHABiLWAMI7vjS2h',
#   '_score': 1.0,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '15:36',
#    'rubrics': 'Медицина',
#    'difficulty': '7.1',
#    'title': 'Эффективность CAR-T против ВИЧ повысили в 50 раз',
#    'author': 'Анна Образцова',
#    'text': '\n\n\nУченые из Пенсильванского университета смогли улучшить Т-лимфоцитамы с химерными антигенными рецепторами (CAR-T) для лечения ВИЧ. В результате клетки стали вырабатывать большее количество действующего белка, их собственная устойчивость к вирусу повысилась, а уровень размножения вируса снизился в 50 раз. Работа опубликована в журнале PLOS Pathogens.\nCAR-T — это метод, позволяющий нацелить Т-лимфоциты на уничтожение конкретного типа клеток. Лимфоциты получают из крови пациента, генетически модифицируют их таким образом, что они производят искусственный белковый рецептор (CAR), а затем возвращают их в кровеносную систему. Рецептор состоит из двух частей — внеклеточной, способной специфически связывать какой-либо белок-мишень, и внутриклеточной — активирующей Т-лимфоцит. Используя CAR, специфичный к опухолевым клеткам, ученые уже разработали способ лечения лейкоза.\nДля борьбы с ВИЧ также уже были получены CAR-T. Терапия уже проходила клеточные испытания, не показала серьезных побочных эффектов, однако эффективность ее была слишком низкой. Авторы работы решили усовершенствовать существующие наработки и пошагово изменили практически все элементы прошлой генетической конструкции.\nВо-первых, они заменили вектор (переносчик генетической информации) c ретровирусного, на лентивирусный. Оба типа векторов встраиваются в геном модифицируемых клеток, однако ретровирусные чаще интегрируются в регуляторную область генов, а лентивирусные — собственно в ген. Ученые предположили, что синтез CAR будет идти эффективнее во втором случае, и перенесли ранее использовавшийся ген в лентивирусный вектор. Эксперименты показали, что возросло как количество интеграций вектора в геном, так и итоговая концентрация CAR.\nВо-вторых, авторы заменили элементы самого гена — промотор (область гена, запускающую его экспрессию) и участок, кодирующий трансмембранный домен рецептора. В изначальной версии CAR трансмембранный домен, соединяющий внеклеточную и внутриклеточную части, был взят из белка CD4. Теперь его заменили на домен из белка CD8α, что не только позволяет рецепторам димеризоваться, но и снижает чувствительность клеток к вирусу (так как для проникновения в лимфоцит ВИЧ необходимо связаться с молекулой CD4).\nПерестроенный CAR-T работает значительно лучше начальной версии — скорость размножения вируса замедляется в 50 раз, что делает данный метод перспективным для терапии. Авторы работы утверждают, то тестирование на пациентах начнутся уже весной 2018 года.\nАнна Образцова\n\n'}},
#  {'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'ewW2FHABiLWAMI7vjS2r',
#   '_score': 1.0,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '14:57',
#    'rubrics': 'Физика',
#    'difficulty': '4.7',
#    'title': 'Физики научились управлять движением топологических дефектов в ионных цепочках',
#    'author': 'Александр Дубов',
#    'text': '\n\n\nДвижением топологических дефектов в кристаллических структурах, которые образуются из ионов в ионных ловушках, можно управлять, изменяя амплитуду внешнего воздействия. Такой эффект группа физиков из Германии и Франции продемонстрировала на зигзагообразных ионных цепочках, состоящих из 34 ионов магния. Результаты исследования опубликованы в Physical Review Letters.\nТопологические дефекты в кристалле — области периодической кристаллической структуры, на которых происходит нарушение симметрии кристалла и одна топологическая фаза сменяется на другую. В трехмерных кристаллах топологическими дефектами являются, например, дислокации (при нарушении симметрии самого кристалла) или скирмионы (при нарушении магнитной симметрии). Топологический дефект может двигаться по кристаллу, формируя солитон — единичную устойчивую волну. Для упорядоченных структур с низкой размерностью и небольшим объемом управление солитонами может оказаться полезным, например, для изменения конфигураций в молекулярных машинах или транспорта ионов через мембранные каналы.\nВ своей работе группа физиков из Германии исследовала кулоновский кристалл, состоящий из 34 ионов Mg+. Такой кристалл представляет из себя квазиодномерную зигзагообразную цепочку, которая имеет две эквивалентных зеркальных конфигурации. Этот кристалл ученые фиксировали в вакуумной ионной ловушке с помощью лазерного охлаждения. При этом конфигурацией цепочки можно управлять, изменяя параметры охлаждающего лазерного пучка, а за ее состоянием наблюдать с помощью флуоресцентной спектроскопии.Кроме того, ученые смогли показать, что если в одной половине кристалла стабилизировать одну из возможных конфигураций, а в другой — вторую, то образуется структура, в середине которой находится «излом» — топологический дефект, на котором происходит смена конформации.\n\n\n\n\n\n\n\n'}},
#  {'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'fAW2FHABiLWAMI7vjS22',
#   '_score': 1.0,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '14:29',
#    'rubrics': 'Биология',
#    'difficulty': '2.1',
#    'title': '«Декретный отпуск» самок шимпанзе спас их детенышей от пожирания самцами',
#    'author': 'Екатерина Русакова',
#    'text': '\n\n\nЯпонские\nприматологи, которые наблюдали за\nшимпанзе (Pan\ntroglodytes),\nобитающими\nв Танзании, описали случай, когда взрослый\nсамец схватил только что родившегося\nдетеныша из своей же группы и съел его.\nИсследователи полагают, что этот случай\nобъясняет поведение самок, которые\nперед родами уединяются, а после — на\nнесколько дней остаются в «декретном\nотпуске». Так у их детенышей повышаются\nшансы на выживание. Статья опубликована\nв Phyical\nAnthropology.\nИнфантицид\n(убийство детенышей взрослыми того же\nвида) довольно часто встречается у\nприматов. Причинами такого поведения\nмогут быть, в том числе, сексуальные\nконфликты. Самец может убить детеныша,\nчьим отцом он не является. После этого\nу матери погибшего младенца быстрее\nнаступает овуляция, а у самца-убийцы\nпоявляется шанс спариться с ней и стать\nотцом ее следующего отпрыска. У видов,\nу которых существует иерархия, например\nу лангуров (род Presbytis),\nтолько доминантный самец имеет право\nспариваться с самками. Если же происходит\n«смена власти», победитель убивает\nдетенышей своего предшественника и\nстановится отцом новых. \n\nДетеныши\nмогут стать и жертвой каннибализма.\nИзвестны случаи, когда шимпанзе убивали\nдетенышей из соседней\n(конкурирующей) или из своей\nгруппы и поедали их. Но ученые до сих\nпор не фиксировали инфантицида только\nчто родившихся младенцев. Возможно,\nпотому, что в природе роды у шимпанзе\nудается наблюдать крайне редко, так как\nони не любят рожать «на публике».\nБеременные самки незадолго до родов\nуединяются, и показываются с детенышем\nв общине через несколько дней. Некоторые\nисследователи считают,\nчто так мать защищает новорожденного\nот немедленного убийства.\nАвторы\nнового исследования с 1990 года наблюдали за одной из общин\nшимпанзе, обитающих в горах Махале на\nзападе Танзании. Описываемый\nинцидент произошел в декабре 2014 года.\nОсновными действующими лицами стали\nсамка по кличке Девота, примерно 14 лет,\nкоторая присоединилась к общине в 2012\nгоду, и самец по кличке Дарвин, 25 лет. На\nмомент описываемых событий он был вторым\nили третьим в иерархии группы. \n\nИсследователи\nнаблюдали за группой из 21 шимпанзе, в\nкоторой было четыре взрослых самца и\nдесять взрослых самок. Девота должна\nбыла вот-вот родить, но наблюдатели не\nзамечали явных признаков\nначала родов: обезьяна не делала гнездо\n(обычно шимпанзе сооружают их для\nночлега), не запихивала руку в вагину,\nчтобы расширить ее, и у нее не отходили\nоколоплодные воды. Внезапно она присела\nи родила. Детеныш упал на землю, откуда\nего немедленно подхватил сидевший за\nДевотой Дарвин и убежал с ним в кусты.\nМать не успела даже взять младенца на\nруки. Примерно через полчаса самец\nпоявился с безжизненным телом детеныша\nна руках, а через некоторое время залез\nна дерево и примерно в течение часа съел\nтруп. На следующий день у Дарвина была\nсильная диарея, поэтому исследователи\nне смогли собрать образцы фекалий с\nкостями или волосами детеныша, чтобы\nпроанализировать их.\nАвторы\nработы предлагают несколько объяснений\nувиденному. Во-первых, это мог быть\nсексуальный  конфликт. Маловероятно,\nчто Дарвин был отцом детеныша Девоты,\nтак как он исчез из поля зрения наблюдателей\nи, по-видимому, из группы, в тот период,\nкогда у Девоты была овуляция и она забеременела. Но так как исследователи не\nсмогли достать образцы тканей младенца\nи сделать анализ ДНК, подтвердить или\nопровергнуть свое предположение они\nне смогли. \n\nВо-вторых,\nДарвин мог съесть детеныша, чтобы\nвосполнить нехватку питательных веществ,\nно последующая диарея свела его усилия\nна нет. Возможно, что самец убил детеныша,\nчтобы впоследствии принудить его мать\nк спариванию. Но так как у исследователей\nне хватало данных о предыдущих и\nпоследующих сексуальных контактах\nДевоты и Дарвина, протестировать это\nпредположение они не смогли.\nЧтобы\nвыяснить, действительно ли беременные\nсамки перед родами уходят из группы (и\nтаким образом предохраняют детеныша\n ...
#  {'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'fQW2FHABiLWAMI7vjS3B',
#   '_score': 1.0,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '14:07',
#    'rubrics': 'Транспорт',
#    'difficulty': '3.4',
#    'title': 'В России разработают судно для перезарядки корабельных реакторов',
#    'author': 'Василий Сычев',
#    'text': '\n\n\nПетербургское конструкторское бюро «Айсберг» в ближайшее время приступит к разработке технического проекта нового многофункционального судна атомно-технологического обслуживания, которое будет использоваться, в том числе, для перезарядки корабельных атомных реакторов. Как сообщает FlotProm, работы будут вестись по заказу Министерства промышленности и торговли России.В настоящее время под управлением «Атомфлота» находится специальное судно «Имандра». Оно используется для перезарядки атомных реакторов российских ледоколов. Это судно было построено в 1980 году и введено в строй годом позже. По оценке специалистов, эта плавучая технологическая база не пригодна для перезарядки корабельных реакторов нового типа, и модернизировать ее невозможно.Согласно требованиям к новому специальному судну, разработкой которого займется «Айсберг», оно будет заниматься обслуживанием судов и плавучих сооружений, оснащенных реакторными установками РИТМ-200, РИТМ-400 и КЛТ-40С. Реакторами РИТМ-200 будут оснащены перспективные российские атомные ледоколы проекта 22220 «Арктика», а КЛТ-40С — плавучая атомная электростанция «Академик Ломоносов».Новое вспомогательное судно также сможет хранить и перевозить новое и отработанное ядерное топливо. На разработку проекта планируется потратить не более 490 миллионов рублей. Как ожидается, опытно-конструкторские работы по проекту будут завершены до конца 2018 года.В июле прошлого года сообщалось, что в 2018 году планируется завершить проектирование ледокола-лидера мощностью 110 мегаватт. Это судно, как ожидается, получит атомный реактор РИТМ-400 тепловой мощностью 350 мегаватт. После завершения разработки конструкторской документации будет приниматься решение о сроках закладки первых секций корабля.Ледокол-лидер также известен как ледокол класса ЛК-110Я. Предпологается, что водоизмещение судна составит 55,6 тысячи тонн при длине 206 метров, ширине 40 метров и высоте 20,3 метра. Корабль получит атомную энергетическую установку и четыре гребных винта. Мощность на валах составит 110 мегаватт.По чистой воде ледокол-лидер сможет развивать скорость до 24 узлов и проводить через льды другие суда на скорости до 12 узлов. В состав экипажа ледокола войдут 127 человек. Судно сможет принимать на борт до 12 пассажиров.Василий Сычёв\n'}}]

# %% [markdown]
# Сам по себе запрос содержит информацию о шардах, найденные документы, их количество, информацию о выполнении запроса.

# %%
res
# Out:
# {'took': 234,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 18, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'nplus1',
#     '_type': 'article',
#     '_id': 'dAW2FHABiLWAMI7vjS0T',
#     '_score': 1.0,
#     '_source': {'date': '16 Окт. 2017',
#      'time': '18:33',
#      'rubrics': 'Медицина',
#      'difficulty': '2.1',
#      'title': 'В донорской крови нашли африканский птичий вирус',
#      'author': 'Дарья Спасская',
#      'text': '\n\n\nАфриканский вирус Усуту, который с начала 2000-х годов вызвал\nв Европе несколько эпидемий среди птиц, встречается у людей чаще, чем\nожидалось. В частности, вирус был обнаружен в семи образцах донорской крови в\nавстрийском донорском центре. Об этом сообщает европейский эпидемиологический\nжурнал Eurosurveillance, а\nо распространении вируса среди птиц на территории Австрии и Венгрии авторы\nрассказали в журнале Emerging Microbes & Infections.\nВирус Усуту\nотносится к группе флавивирусов, так же как вирус энцефалита, лихорадки\nЗападного Нила, денге и вирус Зика. Как и многие представители этой группы,\nпереносится вирус Усуту комарами. Он был впервые описан на территории Африки в\n1959 году, а в 2001 году был зарегистрирован на территории Австрии, где вызвал\nэпидемию энцефалита среди дроздов. С 2003 по 2006 годы в Австрии также нередко\nвстречались случаи заражения диких птиц, однако потом болезнь пошла на спад,\nпо-видимому благодаря выработке иммунитета против вируса. С тех пор и по сей\nдень вспышки вирусной инфекции среди перелетных птиц регистрировали в разных\nстранах Европы, в том числе в Италии, Франции, Германии и других. \nОфициально случаи заражения\nвирусом Усуту людей были подтверждены лишь несколько раз — дважды в Африке, у\nпациентов с лихорадкой, а после в Италии в 2009 году. Два итальянских пациента\nс иммунодефицитом в результате заражения вирусом заболели энцефалитом. Однако,\nисследования, проведенные во время птичьих эпидемий, показали, что антитела\nпротив вируса встречаются у людей не так уж редко. Это означает, что люди регулярно\nзаражаются вирусом, но в подавляющем большинстве случаев инфекция проходит\nбессимптомно. \n В 2014 году австрийский Красный крест, который\nзанимается сбором донорской крови, начал тестировать поступающий к ним материал\nна наличие вируса лихорадки Западного Нила. Летом 2017 года в донорском центре\nбыло обнаружено семь образцов зараженной крови. Дальнейшая проверка не\nподтвердила принадлежность найденной вирусной РНК к искомому виду вируса, зато\nпрояснила, что образцы заражены вирусом Усуту. Как оказалось, все доноры не\nпроявляли никаких клинических симптомов. В тропические страны они не выезжали,\nто есть заразились вирусом на территории Австрии. \nКонечно, факт\nобнаружения неопасного вируса в донорской крови это еще не повод бить тревогу и\nобъявлять эпидемию, однако авторы статьи настаивают, что проверка образцов, а\nвозможно и пациентов, на наличие вируса Усуту, должна стать рутинной процедурой.\nНесмотря на то, что вирус неопасен для здоровых людей, у людей с отягощающими\nфакторами, такими как возраст и наличие других заболеваний, инфекция может\nпривести к развитию неврологических симптомов. К тому же вирусы быстро\nмутируют, а рутинный мониторинг поможет держать ситуацию под контролем и не\nдопустить развития эпидемии в случае появления более опасной формы вируса. Именно\nтак началась эпидемия лихорадки Зика — мы рассказывали, что способность\nвируса Зика поражать клетки-предшественницы нейронов резко повысилась после\nвозникновения единственной мутации в его геноме. \nДарья Спасская\n \n \n\n\n'}},
#    {'_index': 'nplus1',
#     '_type': 'article',
#     '_id': 'dQW2FHABiLWAMI7vjS1m',
#     '_score': 1.0,
#     '_source': {'date': '16 Окт. 2017',
#      'time': '17:50',
#      'rubrics': 'IT',
#      'difficulty': '2.8',
#      'title': 'В протоколе Wi-Fi WPA2 обнаружили критические уязвимости',
#      'author': 'Григорий Копиев',
#      'text': '\n\n\nВ протоколе WPA2, используемом для защиты сетей Wi-Fi, обнаружено несколько критических уязвимостей. Эксплуатация этих уязвимостей позволяет злоумышленникам «подслушивать» трафик в зашифрованных сетях или даже изменять его. Хотя бы части из этих уязвимостей подвержены Windows, macOS, Linux, Android, iOS и другие операционные системы, а также аппаратное обеспечение. Описание атак доступно на специальном сайте, а полностью исследование будет представлено 1 ноября 2017 года на конференции CSS.\nНа данный момент основным протоколом защиты сетей Wi-Fi является WPA2. Его поддержка является обязательной для всех сертифицированных Wi-Fi устройств. Он позволяет предоставлять доступ к сети по паролю, а шифрование трафика в таких сетях происходит с помощью уникального для каждого клиента ключа.\nАтака исследователей направлена на четырехстороннее рукопожатие в алгоритме WPA2. Этот механизм используется для аутентификации каждый раз, когда клиент подключается к защищенной сети. Во время рукопожатия точка доступа и клиент формируют ключ, который затем используется для шифрования и безопасной передачи трафика. Исследователи нашли способ вмешаться в этот механизм таким образом, что жертва будет постоянно использовать один и тот же параметр nonce, предназначенный исключительно для одноразового использования. Это в корне подрывает безопасность протокола и позволяет злоумышленнику получать доступ к пакетам, передаваемым по сети.\n\nИсследователи опубликовали список из десяти уязвимостей. Тем или иным вариантам атак оказались подвержены Android, Linux, macOS, iOS, Windows и OpenBSD, а также аппаратное обеспечение MediaTek, Linksys и других крупных производителей. Наибольшую опасность эти атаки представляют для Linux и Android версии 6.0 и выше. В зависимости от конкретной реализации протокола на той или иной платформе злоумышленник, использующий эти уязвимости, может как читать трафик сети, так и вмешиваться в него, например, внедряя вредоносное программное обеспечение в сайты, просматриваемые пользователем.\nСпециалисты заверили, что для устранения уязвимостей не потребуется вводить новый протокол шифрования, достаточно лишь патчей безопасности. Причем, как отмечают исследователи, такие патчи могут быть обратно совместимыми, то есть даже если уязвимости будут исправлены только у клиента или только у точки доступа, они все равно смогут общаться между собой. По словам исследователей, они еще летом 2017 года контактировали с Координационным центром CERT для того, чтобы совместно оповестить крупные компании до обнародования информации об уязвимостях.\nНедавно критические уязвимости были обнаружены и в другом популярном протоколе связи — Bluetooth. Специалисты, обнаружившие эти уязвимости, заявили, что потенциально им подвержено более восьми миллиардов устройств, в том числе работающих под управлением Windows, Android, iOS и других популярных операционных систем. Для их эксплуатации злоумышленникам даже не нужно физически взаимодействовать с устройством жертвы, достаточно лишь активного Bluetooth-соединения на устройстве жертвы. Многие крупные производители уже выпустили обновления безопасности для своих операционных систем или устройств.\nГригорий Копиев\n'}},
#    {'_index': 'nplus1',
#     '_type': 'article',
#     '_id': 'dgW2FHABiLWAMI7vjS11',
#     '_score': 1.0,
#     '_source': {'date': '16 Окт. 2017',
#      'time': '17:29',
#      'rubrics': 'Астрономия',
#      'difficulty': '4.1',
#      'title': 'Вертолеты помогли описать завихрения в протопланетных дисках',
#      'author': 'Дмитрий Трунин',
#      'text': '\n\n\nАстрофизики из Йельского университета адаптировали алгоритм инженеров, изучавших взаимодействие лопастей вертолета с создаваемыми ими завихрениями воздуха, для описания процессов в протопланетных и аккреционных дисках. Это позволило учесть теорему Кельвина о циркуляции и получить более точные картины процессов. Статья опубликована в журнале The Astrophysical Journal. \nВ процессе формирования протопланетного или аккреционного диска большую роль играют неламинарные течения, в которых формируются вихри и другие долгоживущие структуры. Также такие особенности наблюдаются в атмосферах планет (например, большое красное пятно на Юпитере). Следовательно, численное моделирование таких дисков должно учитывать сильные нелинейности модели.\nИз-за нелинейностей в процессе численного моделирования вычислительные ошибки могут быстро накапливаться. Поэтому хорошие алгоритмы должны быть разработаны таким образом, чтобы в ходе вычислений не нарушались некоторые важные для исследуемого явления законы сохранения. Обычно требуют выполнения законов сохранения энергии и импульса, а также уравнения непрерывности. Однако в протопланетном диске выполняется еще один закон, который все разработанные методы численного моделирования не учитывают, — закон сохранения зави́хренности (теорема Кельвина о циркуляции). В новой работе астрофизики обошли эту проблему.\nДля этого они воспользовались наработками инженеров, изучавших взаимодействие лопастей вертолета с возникающими завихрениями воздуха. В этой задаче также важно следить за сохранением завихренности, чтобы спроектировать более эффективную геометрию винта. Разработанный инженерами алгоритм RBV2 основывается на полулагранжевом методе (semi-Lagrangian scheme) и разложении Гельмгольца-Ходжа (Helmholtz-Hodge decomposition) и отлично описывает случай медленно смещающихся вихрей, хотя и является методом всего второго порядка точности. Астрофизики применили его к моделированию протопланетных дисков практически без изменений.\n\n\n\n\n\n\n'}},
#    {'_index': 'nplus1',
#     '_type': 'article',
#     '_id': 'dwW2FHABiLWAMI7vjS1_',
#     '_score': 1.0,
#     '_source': {'date': '16 Окт. 2017',
#      'time': '17:00',
#      'rubrics': 'Астрономия',
#      'difficulty': '5.2',
#      'title': 'Астрономы впервые услышали гравитационные волны от слияния нейтронных звезд',
#      'author': 'Александр Войтюк',
#      'text': '\n\n\nУченые впервые в истории зафиксировали гравитационные волны от слияния двух нейтронных звезд — сверхплотных объектов массой с наше Солнце и размером с Москву. Возникшие затем гамма-всплеск и вспышку килоновой наблюдали около 70 наземных и космических обсерваторий — они смогли увидеть предсказанный теоретиками процесс синтеза тяжелых элементов, в том числе золота и платины, и подтвердить правоту гипотез о природе загадочных коротких гамма-всплесков, сообщают пресс-служба коллаборации LIGO/Virgo, Европейской Южной обсерватории и обсерватории Лос-Кумбрес. Результаты наблюдений могут пролить свет на загадку строения нейтронных звезд и образование тяжелых элементов во Вселенной.\nУтром 17 августа 2017 года (в 8:41 по времени Восточного побережья США, когда в Москве было 15:41) автоматические системы на одном из двух детекторов гравитационно-волновой обсерватории LIGO зарегистрировали приход гравитационной волны из космоса. Сигнал получил обозначение GW170817, это был уже пятый случай фиксации гравитационных волн с 2015 года, с момента, когда они были впервые зарегистрированы. Всего за три дня до этого обсерватория LIGO впервые «услышала» гравитационную волну вместе с европейским проектом Virgo.\nОднако в этот раз уже через две секунды после гравитационного события космический телескоп Fermi зафиксировал вспышку гамма-излучения на южном небе. Почти в этот же момент вспышку увидела европейско-российская космическая обсерватория INTEGRAL.\nАвтоматические системы анализа данных обсерватории LIGO пришли к выводу, что случайное совпадение этих двух событий крайне маловероятно. В ходе поиска дополнительной информации было обнаружено, что гравитационную волну увидел и второй детектор LIGO, но не зафиксировала европейская гравитационная обсерватория Virgo. Астрономы всего мира были подняты «по тревоге» — охоту на источник гравитационных волн и гамма-всплеска начали множество обсерваторий, в том числе Европейская Южная обсерватория и космический телескоп Hubble.\n\n\n\n\n\n\n'}},
#    {'_index': 'nplus1',
#     '_type': 'article',
#     '_id': 'eAW2FHABiLWAMI7vjS2N',
#     '_score': 1.0,
#     '_source': {'date': '16 Окт. 2017',
#      'time': '16:22',
#      'rubrics': 'Роботы и дроны',
#      'difficulty': '3.1',
#      'title': 'Японцы представили сельскохозяйственный дрон',
#      'author': 'Василий Сычев',
#      'text': '\n\n\nЯпонская компания Yamaha представила сельскохозяйственный дрон YMR-01, который можно использовать для распыления различных химикатов над полями. Как пишет Aviation Week, продажи нового беспилотного летательного аппарата начнутся в 2018 году.В сельскохозяйственной отрасли Yamaha известна в качестве производителя дистанционно управляемых вертолетов Rmax и Fazer. Это крупные машины длиной 3,7 и 2,6 метра соответственно. Они предназначены для обработки больших по площади полей. В настоящее время в сельском хозяйстве используются около 2,5 тысячи таких машин.YMR-01 представляет собой существенно более дешевую альтернативу дистанционно управляемым вертолетам. Один такой аппарат сможет распылять химикаты над полем площадью до 10,1 тысячи квадратных метров. Беспилотник получил распыляющие системы компании Yamabiko, которая и будет продавать YMR-01 через свою дилерскую сеть.Новый дрон выполнен по схеме гексакоптера. Передние и задние два его луча оснащены электромоторами с верхним расположением воздушных винтов. Боковые два луча имеют электромоторы с двумя воздушными соосными винтами, один из которых расположен снизу, а второй — сверху. В полете такие винты, по оценке Yamaha, создают равномерный воздушный поток.Соосно боковым воздушным винтам расположены и форсунки распылителей химикатов. В Yamaha утверждают, что такое расположение распылителей позволяет добиться более равномерного осаждения химикатов на поля. Другие подробности о проекте не уточняются.В конце 2015 года собственный сельскохозяйственный дрон представила китайская компания DJI. Октокоптер Agras MG-1 предназначен для обработки выращиваемых культур пестицидами. На складывающихся плечах беспилотника смонтирована система трубок и разбрызгивающих форсунок, а под корпусом находится емкость вместимостью десять литров. За час MG-1 может обработать участок площадью в три-четыре гектара.Во время распыления дрон самостоятельно регулирует количество выбрасываемых пестицидов в зависимости от скорости передвижения. Также при необходимости вернуться MG-1 запоминает точку, на которой он остановился, и продолжает работу с нее.Василий Сычёв\n'}},
#    {'_index': 'nplus1',
#     '_type': 'article',
#     '_id': 'eQW2FHABiLWAMI7vjS2Y',
#     '_score': 1.0,
#     '_source': {'date': '16 Окт. 2017',
#      'time': '16:02',
#      'rubrics': 'Космонавтика',
#      'difficulty': '1.7',
#      'title': 'Китайская орбитальная станция «Тяньгун-1» упадет на Землю в конце года',
#      'author': 'Кристина Уласович',
#      'text': '\n\n\nПервая китайская орбитальная космическая станция «Тяньгун-1» упадет на поверхность Земли в конце 2017 — начале 2018 года. Об этом сообщает The Guardian.\nКосмический аппарат «Тяньгун-1», также именуемый целевым модулем, стал первой не советской и не американской орбитальной станцией. Он представляет собой прототип более крупной станции, которая начнет работу в начале 2020-х годов. Корабль, предназначенный для отработки технологий сближения и стыковки космических аппаратов, был запущен в космос сентябре 2011 года. Станция весит 8,5 тонн и в длину достигает 10,4 метров. Корабль использовался как для научных экспериментов, например для съемки земной поверхности, так и для пилотируемых миссий. Модуль способен обеспечивать жизнедеятельность 3 космонавтов в течение 20 суток. В 2012 году его посетила первая в Китае женщина-космонавт Лю Ян. \nВ 2016 году власти Китая сообщили, что они потеряли возможность корректировать орбиту «Тяньгун-1» и ожидают, что станция упадет на Землю в период с октября 2017 года по апрель 2018 года. Однако совсем недавно стало известно, что корабль вошел в более плотные слои атмосферы нашей планеты и скорость его снижения увеличилась. Согласно новым прогнозам, «Тяньгун-1» упадет на поверхность в ближайшие несколько месяцев.\nБольшая часть космического аппарата должна сгореть в атмосфере Земли, однако эксперты отмечают, что некоторые куски весом до 100 килограмм могут уцелеть. Шансы на то, что они попадут в населенный пункт, малы, однако «Комитет по использованию космического пространства в мирных целях» (COPUOS) будет следить за обломками станции и информировать членов ООН о ходе развития событий.В апреле 2017 года на орбиту вышел первый китайский космический грузовик — «Тяньчжоу-1». Ранее китайское национальное космическое управление и Управление ООН по вопросам космического пространства (UNOOSA) заключили соглашение, согласно которому Китай предоставит возможность странам-участницам ООН использовать свою будущую космическую станцию — ее запуск намечен на 2022 год.\nКристина Уласович\n'}},
#    {'_index': 'nplus1',
#     '_type': 'article',
#     '_id': 'egW2FHABiLWAMI7vjS2h',
#     '_score': 1.0,
#     '_source': {'date': '16 Окт. 2017',
#      'time': '15:36',
#      'rubrics': 'Медицина',
#      'difficulty': '7.1',
#      'title': 'Эффективность CAR-T против ВИЧ повысили в 50 раз',
#      'author': 'Анна Образцова',
#      'text': '\n\n\nУченые из Пенсильванского университета смогли улучшить Т-лимфоцитамы с химерными антигенными рецепторами (CAR-T) для лечения ВИЧ. В результате клетки стали вырабатывать большее количество действующего белка, их собственная устойчивость к вирусу повысилась, а уровень размножения вируса снизился в 50 раз. Работа опубликована в журнале PLOS Pathogens.\nCAR-T — это метод, позволяющий нацелить Т-лимфоциты на уничтожение конкретного типа клеток. Лимфоциты получают из крови пациента, генетически модифицируют их таким образом, что они производят искусственный белковый рецептор (CAR), а затем возвращают их в кровеносную систему. Рецептор состоит из двух частей — внеклеточной, способной специфически связывать какой-либо белок-мишень, и внутриклеточной — активирующей Т-лимфоцит. Используя CAR, специфичный к опухолевым клеткам, ученые уже разработали способ лечения лейкоза.\nДля борьбы с ВИЧ также уже были получены CAR-T. Терапия уже проходила клеточные испытания, не показала серьезных побочных эффектов, однако эффективность ее была слишком низкой. Авторы работы решили усовершенствовать существующие наработки и пошагово изменили практически все элементы прошлой генетической конструкции.\nВо-первых, они заменили вектор (переносчик генетической информации) c ретровирусного, на лентивирусный. Оба типа векторов встраиваются в геном модифицируемых клеток, однако ретровирусные чаще интегрируются в регуляторную область генов, а лентивирусные — собственно в ген. Ученые предположили, что синтез CAR будет идти эффективнее во втором случае, и перенесли ранее использовавшийся ген в лентивирусный вектор. Эксперименты показали, что возросло как количество интеграций вектора в геном, так и итоговая концентрация CAR.\nВо-вторых, авторы заменили элементы самого гена — промотор (область гена, запускающую его экспрессию) и участок, кодирующий трансмембранный домен рецептора. В изначальной версии CAR трансмембранный домен, соединяющий внеклеточную и внутриклеточную части, был взят из белка CD4. Теперь его заменили на домен из белка CD8α, что не только позволяет рецепторам димеризоваться, но и снижает чувствительность клеток к вирусу (так как для проникновения в лимфоцит ВИЧ необходимо связаться с молекулой CD4).\nПерестроенный CAR-T работает значительно лучше начальной версии — скорость размножения вируса замедляется в 50 раз, что делает данный метод перспективным для терапии. Авторы работы утверждают, то тестирование на пациентах начнутся уже весной 2018 года.\nАнна Образцова\n\n'}},
#    {'_index': 'nplus1',
#     '_type': 'article',
#     '_id': 'ewW2FHABiLWAMI7vjS2r',
#     '_score': 1.0,
#     '_source': {'date': '16 Окт. 2017',
#      'time': '14:57',
#      'rubrics': 'Физика',
#      'difficulty': '4.7',
#      'title': 'Физики научились управлять движением топологических дефектов в ионных цепочках',
#      'author': 'Александр Дубов',
#      'text': '\n\n\nДвижением топологических дефектов в кристаллических структурах, которые образуются из ионов в ионных ловушках, можно управлять, изменяя амплитуду внешнего воздействия. Такой эффект группа физиков из Германии и Франции продемонстрировала на зигзагообразных ионных цепочках, состоящих из 34 ионов магния. Результаты исследования опубликованы в Physical Review Letters.\nТопологические дефекты в кристалле — области периодической кристаллической структуры, на которых происходит нарушение симметрии кристалла и одна топологическая фаза сменяется на другую. В трехмерных кристаллах топологическими дефектами являются, например, дислокации (при нарушении симметрии самого кристалла) или скирмионы (при нарушении магнитной симметрии). Топологический дефект может двигаться по кристаллу, формируя солитон — единичную устойчивую волну. Для упорядоченных структур с низкой размерностью и небольшим объемом управление солитонами может оказаться полезным, например, для изменения конфигураций в молекулярных машинах или транспорта ионов через мембранные каналы.\nВ своей работе группа физиков из Германии исследовала кулоновский кристалл, состоящий из 34 ионов Mg+. Такой кристалл представляет из себя квазиодномерную зигзагообразную цепочку, которая имеет две эквивалентных зеркальных конфигурации. Этот кристалл ученые фиксировали в вакуумной ионной ловушке с помощью лазерного охлаждения. При этом конфигурацией цепочки можно управлять, изменяя параметры охлаждающего лазерного пучка, а за ее состоянием наблюдать с помощью флуоресцентной спектроскопии.Кроме того, ученые смогли показать, что если в одной половине кристалла стабилизировать одну из возможных конфигураций, а в другой — вторую, то образуется структура, в середине которой находится «излом» — топологический дефект, на котором происходит смена конформации.\n\n\n\n\n\n\n\n'}},
#    {'_index': 'nplus1',
#     '_type': 'article',
#     '_id': 'fAW2FHABiLWAMI7vjS22',
#     '_score': 1.0,
#     '_source': {'date': '16 Окт. 2017',
#      'time': '14:29',
#      'rubrics': 'Биология',
#      'difficulty': '2.1',
#      'title': '«Декретный отпуск» самок шимпанзе спас их детенышей от пожирания самцами',
#      'author': 'Екатерина Русакова',
#      'text': '\n\n\nЯпонские\nприматологи, которые наблюдали за\nшимпанзе (Pan\ntroglodytes),\nобитающими\nв Танзании, описали случай, когда взрослый\nсамец схватил только что родившегося\nдетеныша из своей же группы и съел его.\nИсследователи полагают, что этот случай\nобъясняет поведение самок, которые\nперед родами уединяются, а после — на\nнесколько дней остаются в «декретном\nотпуске». Так у их детенышей повышаются\nшансы на выживание. Статья опубликована\nв Phyical\nAnthropology.\nИнфантицид\n(убийство детенышей взрослыми того же\nвида) довольно часто встречается у\nприматов. Причинами такого поведения\nмогут быть, в том числе, сексуальные\nконфликты. Самец может убить детеныша,\nчьим отцом он не является. После этого\nу матери погибшего младенца быстрее\nнаступает овуляция, а у самца-убийцы\nпоявляется шанс спариться с ней и стать\nотцом ее следующего отпрыска. У видов,\nу которых существует иерархия, например\nу лангуров (род Presbytis),\nтолько доминантный самец имеет право\nспариваться с самками. Если же происходит\n«смена власти», победитель убивает\nдетенышей своего предшественника и\nстановится отцом новых. \n\nДетеныши\nмогут стать и жертвой каннибализма.\nИзвестны случаи, когда шимпанзе убивали\nдетенышей из соседней\n(конкурирующей) или из своей\nгруппы и поедали их. Но ученые до сих\nпор не фиксировали инфантицида только\nчто родившихся младенцев. Возможно,\nпотому, что в природе роды у шимпанзе\nудается наблюдать крайне редко, так как\nони не любят рожать «на публике».\nБеременные самки незадолго до родов\nуединяются, и показываются с детенышем\nв общине через несколько дней. Некоторые\nисследователи считают,\nчто так мать защищает новорожденного\nот немедленного убийства.\nАвторы\nнового исследования с 1990 года наблюдали за одной из общин\nшимпанзе, обитающих в горах Махале на\nзападе Танзании. Описываемый\nинцидент произошел в декабре 2014 года.\nОсновными действующими лицами стали\nсамка по кличке Девота, примерно 14 лет,\nкоторая присоединилась к общине в 2012\nгоду, и самец по кличке Дарвин, 25 лет. На\nмомент описываемых событий он был вторым\nили третьим в иерархии группы. \n\nИсследователи\nнаблюдали за группой из 21 шимпанзе, в\nкоторой было четыре взрослых самца и\nдесять взрослых самок. Девота должна\nбыла вот-вот родить, но наблюдатели не\nзамечали явных признаков\nначала родов: обезьяна не делала гнездо\n(обычно шимпанзе сооружают их для\nночлега), не запихивала руку в вагину,\nчтобы расширить ее, и у нее не отходили\nоколоплодные воды. Внезапно она присела\nи родила. Детеныш упал на землю, откуда\nего немедленно подхватил сидевший за\nДевотой Дарвин и убежал с ним в кусты.\nМать не успела даже взять младенца на\nруки. Примерно через полчаса самец\nпоявился с безжизненным телом детеныша\nна руках, а через некоторое время залез\nна дерево и примерно в течение часа съел\nтруп. На следующий день у Дарвина была\nсильная диарея, поэтому исследователи\nне смогли собрать образцы фекалий с\nкостями или волосами детеныша, чтобы\nпроанализировать их.\nАвторы\nработы предлагают несколько объяснений\nувиденному. Во-первых, это мог быть\nсексуальный  конфликт. Маловероятно,\nчто Дарвин был отцом детеныша Девоты,\nтак как он исчез из поля зрения наблюдателей\nи, по-видимому, из группы, в тот период,\nкогда у Девоты была овуляция и она забеременела. Но так как исследователи не\nсмогли достать образцы тканей младенца\nи сделать анализ ДНК, подтвердить или\nопровергнуть свое предположение они\nне смогли. \n\nВо-вторых,\nДарвин мог съесть детеныша, чтобы\nвосполнить нехватку питательных веществ,\nно последующая диарея свела его усилия\nна нет. Возможно, что самец убил детеныша,\nчтобы впоследствии принудить его мать\nк спариванию. Но так как у исследователей\nне хватало данных о предыдущих и\nпоследующих сексуальных контактах\nДевоты и Дарвина, протестировать это\nпредположение они не смогли.\nЧтобы\nвыяснить, действительно ли беременные\nсамки перед родами уходят из группы (и\nтаким образом предохраняют детеныша ...
#    {'_index': 'nplus1',
#     '_type': 'article',
#     '_id': 'fQW2FHABiLWAMI7vjS3B',
#     '_score': 1.0,
#     '_source': {'date': '16 Окт. 2017',
#      'time': '14:07',
#      'rubrics': 'Транспорт',
#      'difficulty': '3.4',
#      'title': 'В России разработают судно для перезарядки корабельных реакторов',
#      'author': 'Василий Сычев',
#      'text': '\n\n\nПетербургское конструкторское бюро «Айсберг» в ближайшее время приступит к разработке технического проекта нового многофункционального судна атомно-технологического обслуживания, которое будет использоваться, в том числе, для перезарядки корабельных атомных реакторов. Как сообщает FlotProm, работы будут вестись по заказу Министерства промышленности и торговли России.В настоящее время под управлением «Атомфлота» находится специальное судно «Имандра». Оно используется для перезарядки атомных реакторов российских ледоколов. Это судно было построено в 1980 году и введено в строй годом позже. По оценке специалистов, эта плавучая технологическая база не пригодна для перезарядки корабельных реакторов нового типа, и модернизировать ее невозможно.Согласно требованиям к новому специальному судну, разработкой которого займется «Айсберг», оно будет заниматься обслуживанием судов и плавучих сооружений, оснащенных реакторными установками РИТМ-200, РИТМ-400 и КЛТ-40С. Реакторами РИТМ-200 будут оснащены перспективные российские атомные ледоколы проекта 22220 «Арктика», а КЛТ-40С — плавучая атомная электростанция «Академик Ломоносов».Новое вспомогательное судно также сможет хранить и перевозить новое и отработанное ядерное топливо. На разработку проекта планируется потратить не более 490 миллионов рублей. Как ожидается, опытно-конструкторские работы по проекту будут завершены до конца 2018 года.В июле прошлого года сообщалось, что в 2018 году планируется завершить проектирование ледокола-лидера мощностью 110 мегаватт. Это судно, как ожидается, получит атомный реактор РИТМ-400 тепловой мощностью 350 мегаватт. После завершения разработки конструкторской документации будет приниматься решение о сроках закладки первых секций корабля.Ледокол-лидер также известен как ледокол класса ЛК-110Я. Предпологается, что водоизмещение судна составит 55,6 тысячи тонн при длине 206 метров, ширине 40 метров и высоте 20,3 метра. Корабль получит атомную энергетическую установку и четыре гребных винта. Мощность на валах составит 110 мегаватт.По чистой воде ледокол-лидер сможет развивать скорость до 24 узлов и проводить через льды другие суда на скорости до 12 узлов. В состав экипажа ледокола войдут 127 человек. Судно сможет принимать на борт до 12 пассажиров.Василий Сычёв\n'}}]}}

# %% [markdown]
# В качестве описания документов можно передать более конкретное описание, задаваемое ключевым словом `match`. Ниже мы просим найти все документы, поле `title` которых содержит слово `пустота`.
#
# Если теперь вернуться к описанию типа (маппингу), то мы увидим, что поле `title` задавалось типом `text` с русским анализатором. Это означает, что все слова в документе будут приведены к начальной форме и поиск по ним будет вестись вне зависимости от формы слова. Если мы забудем задать русский язык, то по умолчанию возьмется английский, то есть нормального ндексирования и поиска не получится. Если бы хотели искать по точному совпадению значения поля, то следовало бы использовать тип `keyword`. Также можно использовать другие типы: `integer`, `float`, `date` и другие. Для всех полей можно задать форматирование, которое зависит от типа данных. В нашем случае мы задали, что время содержит в себе часы и минуты.

# %%
res = es.search(index="nplus1", body={"query": {"match": {"title": "донорская"}}})
res["hits"]["hits"]
# Out:
# [{'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'dAW2FHABiLWAMI7vjS0T',
#   '_score': 2.6472712,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '18:33',
#    'rubrics': 'Медицина',
#    'difficulty': '2.1',
#    'title': 'В донорской крови нашли африканский птичий вирус',
#    'author': 'Дарья Спасская',
#    'text': '\n\n\nАфриканский вирус Усуту, который с начала 2000-х годов вызвал\nв Европе несколько эпидемий среди птиц, встречается у людей чаще, чем\nожидалось. В частности, вирус был обнаружен в семи образцах донорской крови в\nавстрийском донорском центре. Об этом сообщает европейский эпидемиологический\nжурнал Eurosurveillance, а\nо распространении вируса среди птиц на территории Австрии и Венгрии авторы\nрассказали в журнале Emerging Microbes & Infections.\nВирус Усуту\nотносится к группе флавивирусов, так же как вирус энцефалита, лихорадки\nЗападного Нила, денге и вирус Зика. Как и многие представители этой группы,\nпереносится вирус Усуту комарами. Он был впервые описан на территории Африки в\n1959 году, а в 2001 году был зарегистрирован на территории Австрии, где вызвал\nэпидемию энцефалита среди дроздов. С 2003 по 2006 годы в Австрии также нередко\nвстречались случаи заражения диких птиц, однако потом болезнь пошла на спад,\nпо-видимому благодаря выработке иммунитета против вируса. С тех пор и по сей\nдень вспышки вирусной инфекции среди перелетных птиц регистрировали в разных\nстранах Европы, в том числе в Италии, Франции, Германии и других. \nОфициально случаи заражения\nвирусом Усуту людей были подтверждены лишь несколько раз — дважды в Африке, у\nпациентов с лихорадкой, а после в Италии в 2009 году. Два итальянских пациента\nс иммунодефицитом в результате заражения вирусом заболели энцефалитом. Однако,\nисследования, проведенные во время птичьих эпидемий, показали, что антитела\nпротив вируса встречаются у людей не так уж редко. Это означает, что люди регулярно\nзаражаются вирусом, но в подавляющем большинстве случаев инфекция проходит\nбессимптомно. \n В 2014 году австрийский Красный крест, который\nзанимается сбором донорской крови, начал тестировать поступающий к ним материал\nна наличие вируса лихорадки Западного Нила. Летом 2017 года в донорском центре\nбыло обнаружено семь образцов зараженной крови. Дальнейшая проверка не\nподтвердила принадлежность найденной вирусной РНК к искомому виду вируса, зато\nпрояснила, что образцы заражены вирусом Усуту. Как оказалось, все доноры не\nпроявляли никаких клинических симптомов. В тропические страны они не выезжали,\nто есть заразились вирусом на территории Австрии. \nКонечно, факт\nобнаружения неопасного вируса в донорской крови это еще не повод бить тревогу и\nобъявлять эпидемию, однако авторы статьи настаивают, что проверка образцов, а\nвозможно и пациентов, на наличие вируса Усуту, должна стать рутинной процедурой.\nНесмотря на то, что вирус неопасен для здоровых людей, у людей с отягощающими\nфакторами, такими как возраст и наличие других заболеваний, инфекция может\nпривести к развитию неврологических симптомов. К тому же вирусы быстро\nмутируют, а рутинный мониторинг поможет держать ситуацию под контролем и не\nдопустить развития эпидемии в случае появления более опасной формы вируса. Именно\nтак началась эпидемия лихорадки Зика — мы рассказывали, что способность\nвируса Зика поражать клетки-предшественницы нейронов резко повысилась после\nвозникновения единственной мутации в его геноме. \nДарья Спасская\n \n \n\n\n'}}]

# %%
res
# Out:
# {'took': 2,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1, 'relation': 'eq'},
#   'max_score': 2.6472712,
#   'hits': [{'_index': 'nplus1',
#     '_type': 'article',
#     '_id': 'dAW2FHABiLWAMI7vjS0T',
#     '_score': 2.6472712,
#     '_source': {'date': '16 Окт. 2017',
#      'time': '18:33',
#      'rubrics': 'Медицина',
#      'difficulty': '2.1',
#      'title': 'В донорской крови нашли африканский птичий вирус',
#      'author': 'Дарья Спасская',
#      'text': '\n\n\nАфриканский вирус Усуту, который с начала 2000-х годов вызвал\nв Европе несколько эпидемий среди птиц, встречается у людей чаще, чем\nожидалось. В частности, вирус был обнаружен в семи образцах донорской крови в\nавстрийском донорском центре. Об этом сообщает европейский эпидемиологический\nжурнал Eurosurveillance, а\nо распространении вируса среди птиц на территории Австрии и Венгрии авторы\nрассказали в журнале Emerging Microbes & Infections.\nВирус Усуту\nотносится к группе флавивирусов, так же как вирус энцефалита, лихорадки\nЗападного Нила, денге и вирус Зика. Как и многие представители этой группы,\nпереносится вирус Усуту комарами. Он был впервые описан на территории Африки в\n1959 году, а в 2001 году был зарегистрирован на территории Австрии, где вызвал\nэпидемию энцефалита среди дроздов. С 2003 по 2006 годы в Австрии также нередко\nвстречались случаи заражения диких птиц, однако потом болезнь пошла на спад,\nпо-видимому благодаря выработке иммунитета против вируса. С тех пор и по сей\nдень вспышки вирусной инфекции среди перелетных птиц регистрировали в разных\nстранах Европы, в том числе в Италии, Франции, Германии и других. \nОфициально случаи заражения\nвирусом Усуту людей были подтверждены лишь несколько раз — дважды в Африке, у\nпациентов с лихорадкой, а после в Италии в 2009 году. Два итальянских пациента\nс иммунодефицитом в результате заражения вирусом заболели энцефалитом. Однако,\nисследования, проведенные во время птичьих эпидемий, показали, что антитела\nпротив вируса встречаются у людей не так уж редко. Это означает, что люди регулярно\nзаражаются вирусом, но в подавляющем большинстве случаев инфекция проходит\nбессимптомно. \n В 2014 году австрийский Красный крест, который\nзанимается сбором донорской крови, начал тестировать поступающий к ним материал\nна наличие вируса лихорадки Западного Нила. Летом 2017 года в донорском центре\nбыло обнаружено семь образцов зараженной крови. Дальнейшая проверка не\nподтвердила принадлежность найденной вирусной РНК к искомому виду вируса, зато\nпрояснила, что образцы заражены вирусом Усуту. Как оказалось, все доноры не\nпроявляли никаких клинических симптомов. В тропические страны они не выезжали,\nто есть заразились вирусом на территории Австрии. \nКонечно, факт\nобнаружения неопасного вируса в донорской крови это еще не повод бить тревогу и\nобъявлять эпидемию, однако авторы статьи настаивают, что проверка образцов, а\nвозможно и пациентов, на наличие вируса Усуту, должна стать рутинной процедурой.\nНесмотря на то, что вирус неопасен для здоровых людей, у людей с отягощающими\nфакторами, такими как возраст и наличие других заболеваний, инфекция может\nпривести к развитию неврологических симптомов. К тому же вирусы быстро\nмутируют, а рутинный мониторинг поможет держать ситуацию под контролем и не\nдопустить развития эпидемии в случае появления более опасной формы вируса. Именно\nтак началась эпидемия лихорадки Зика — мы рассказывали, что способность\nвируса Зика поражать клетки-предшественницы нейронов резко повысилась после\nвозникновения единственной мутации в его геноме. \nДарья Спасская\n \n \n\n\n'}}]}}

# %% [markdown]
# Если мы хотим искать очень условный стем формы слова, следует использовать ключевое слово `term`.

# %%
res = es.search(index="nplus1", body={"query": {"term": {"title": "африканск"}}})
res["hits"]["hits"]
# Out:
# [{'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'dAW2FHABiLWAMI7vjS0T',
#   '_score': 2.6472712,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '18:33',
#    'rubrics': 'Медицина',
#    'difficulty': '2.1',
#    'title': 'В донорской крови нашли африканский птичий вирус',
#    'author': 'Дарья Спасская',
#    'text': '\n\n\nАфриканский вирус Усуту, который с начала 2000-х годов вызвал\nв Европе несколько эпидемий среди птиц, встречается у людей чаще, чем\nожидалось. В частности, вирус был обнаружен в семи образцах донорской крови в\nавстрийском донорском центре. Об этом сообщает европейский эпидемиологический\nжурнал Eurosurveillance, а\nо распространении вируса среди птиц на территории Австрии и Венгрии авторы\nрассказали в журнале Emerging Microbes & Infections.\nВирус Усуту\nотносится к группе флавивирусов, так же как вирус энцефалита, лихорадки\nЗападного Нила, денге и вирус Зика. Как и многие представители этой группы,\nпереносится вирус Усуту комарами. Он был впервые описан на территории Африки в\n1959 году, а в 2001 году был зарегистрирован на территории Австрии, где вызвал\nэпидемию энцефалита среди дроздов. С 2003 по 2006 годы в Австрии также нередко\nвстречались случаи заражения диких птиц, однако потом болезнь пошла на спад,\nпо-видимому благодаря выработке иммунитета против вируса. С тех пор и по сей\nдень вспышки вирусной инфекции среди перелетных птиц регистрировали в разных\nстранах Европы, в том числе в Италии, Франции, Германии и других. \nОфициально случаи заражения\nвирусом Усуту людей были подтверждены лишь несколько раз — дважды в Африке, у\nпациентов с лихорадкой, а после в Италии в 2009 году. Два итальянских пациента\nс иммунодефицитом в результате заражения вирусом заболели энцефалитом. Однако,\nисследования, проведенные во время птичьих эпидемий, показали, что антитела\nпротив вируса встречаются у людей не так уж редко. Это означает, что люди регулярно\nзаражаются вирусом, но в подавляющем большинстве случаев инфекция проходит\nбессимптомно. \n В 2014 году австрийский Красный крест, который\nзанимается сбором донорской крови, начал тестировать поступающий к ним материал\nна наличие вируса лихорадки Западного Нила. Летом 2017 года в донорском центре\nбыло обнаружено семь образцов зараженной крови. Дальнейшая проверка не\nподтвердила принадлежность найденной вирусной РНК к искомому виду вируса, зато\nпрояснила, что образцы заражены вирусом Усуту. Как оказалось, все доноры не\nпроявляли никаких клинических симптомов. В тропические страны они не выезжали,\nто есть заразились вирусом на территории Австрии. \nКонечно, факт\nобнаружения неопасного вируса в донорской крови это еще не повод бить тревогу и\nобъявлять эпидемию, однако авторы статьи настаивают, что проверка образцов, а\nвозможно и пациентов, на наличие вируса Усуту, должна стать рутинной процедурой.\nНесмотря на то, что вирус неопасен для здоровых людей, у людей с отягощающими\nфакторами, такими как возраст и наличие других заболеваний, инфекция может\nпривести к развитию неврологических симптомов. К тому же вирусы быстро\nмутируют, а рутинный мониторинг поможет держать ситуацию под контролем и не\nдопустить развития эпидемии в случае появления более опасной формы вируса. Именно\nтак началась эпидемия лихорадки Зика — мы рассказывали, что способность\nвируса Зика поражать клетки-предшественницы нейронов резко повысилась после\nвозникновения единственной мутации в его геноме. \nДарья Спасская\n \n \n\n\n'}}]

# %% [markdown]
# БД ищет любые слова из запроса за исключением стоп-слов. Порядок слов при этом не важен. Наличие слов в итоговом документе в итоге влияет на поле `_score`, высчитываемое на основе меры tf*idf.

# %%
res = es.search(index="nplus1", body={"query": {"match": {"text": "Германии и Франции"}}})
res["hits"]["hits"]
# Out:
# [{'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'ewW2FHABiLWAMI7vjS2r',
#   '_score': 5.4853954,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '14:57',
#    'rubrics': 'Физика',
#    'difficulty': '4.7',
#    'title': 'Физики научились управлять движением топологических дефектов в ионных цепочках',
#    'author': 'Александр Дубов',
#    'text': '\n\n\nДвижением топологических дефектов в кристаллических структурах, которые образуются из ионов в ионных ловушках, можно управлять, изменяя амплитуду внешнего воздействия. Такой эффект группа физиков из Германии и Франции продемонстрировала на зигзагообразных ионных цепочках, состоящих из 34 ионов магния. Результаты исследования опубликованы в Physical Review Letters.\nТопологические дефекты в кристалле — области периодической кристаллической структуры, на которых происходит нарушение симметрии кристалла и одна топологическая фаза сменяется на другую. В трехмерных кристаллах топологическими дефектами являются, например, дислокации (при нарушении симметрии самого кристалла) или скирмионы (при нарушении магнитной симметрии). Топологический дефект может двигаться по кристаллу, формируя солитон — единичную устойчивую волну. Для упорядоченных структур с низкой размерностью и небольшим объемом управление солитонами может оказаться полезным, например, для изменения конфигураций в молекулярных машинах или транспорта ионов через мембранные каналы.\nВ своей работе группа физиков из Германии исследовала кулоновский кристалл, состоящий из 34 ионов Mg+. Такой кристалл представляет из себя квазиодномерную зигзагообразную цепочку, которая имеет две эквивалентных зеркальных конфигурации. Этот кристалл ученые фиксировали в вакуумной ионной ловушке с помощью лазерного охлаждения. При этом конфигурацией цепочки можно управлять, изменяя параметры охлаждающего лазерного пучка, а за ее состоянием наблюдать с помощью флуоресцентной спектроскопии.Кроме того, ученые смогли показать, что если в одной половине кристалла стабилизировать одну из возможных конфигураций, а в другой — вторую, то образуется структура, в середине которой находится «излом» — топологический дефект, на котором происходит смена конформации.\n\n\n\n\n\n\n\n'}},
#  {'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'dAW2FHABiLWAMI7vjS0T',
#   '_score': 3.6001692,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '18:33',
#    'rubrics': 'Медицина',
#    'difficulty': '2.1',
#    'title': 'В донорской крови нашли африканский птичий вирус',
#    'author': 'Дарья Спасская',
#    'text': '\n\n\nАфриканский вирус Усуту, который с начала 2000-х годов вызвал\nв Европе несколько эпидемий среди птиц, встречается у людей чаще, чем\nожидалось. В частности, вирус был обнаружен в семи образцах донорской крови в\nавстрийском донорском центре. Об этом сообщает европейский эпидемиологический\nжурнал Eurosurveillance, а\nо распространении вируса среди птиц на территории Австрии и Венгрии авторы\nрассказали в журнале Emerging Microbes & Infections.\nВирус Усуту\nотносится к группе флавивирусов, так же как вирус энцефалита, лихорадки\nЗападного Нила, денге и вирус Зика. Как и многие представители этой группы,\nпереносится вирус Усуту комарами. Он был впервые описан на территории Африки в\n1959 году, а в 2001 году был зарегистрирован на территории Австрии, где вызвал\nэпидемию энцефалита среди дроздов. С 2003 по 2006 годы в Австрии также нередко\nвстречались случаи заражения диких птиц, однако потом болезнь пошла на спад,\nпо-видимому благодаря выработке иммунитета против вируса. С тех пор и по сей\nдень вспышки вирусной инфекции среди перелетных птиц регистрировали в разных\nстранах Европы, в том числе в Италии, Франции, Германии и других. \nОфициально случаи заражения\nвирусом Усуту людей были подтверждены лишь несколько раз — дважды в Африке, у\nпациентов с лихорадкой, а после в Италии в 2009 году. Два итальянских пациента\nс иммунодефицитом в результате заражения вирусом заболели энцефалитом. Однако,\nисследования, проведенные во время птичьих эпидемий, показали, что антитела\nпротив вируса встречаются у людей не так уж редко. Это означает, что люди регулярно\nзаражаются вирусом, но в подавляющем большинстве случаев инфекция проходит\nбессимптомно. \n В 2014 году австрийский Красный крест, который\nзанимается сбором донорской крови, начал тестировать поступающий к ним материал\nна наличие вируса лихорадки Западного Нила. Летом 2017 года в донорском центре\nбыло обнаружено семь образцов зараженной крови. Дальнейшая проверка не\nподтвердила принадлежность найденной вирусной РНК к искомому виду вируса, зато\nпрояснила, что образцы заражены вирусом Усуту. Как оказалось, все доноры не\nпроявляли никаких клинических симптомов. В тропические страны они не выезжали,\nто есть заразились вирусом на территории Австрии. \nКонечно, факт\nобнаружения неопасного вируса в донорской крови это еще не повод бить тревогу и\nобъявлять эпидемию, однако авторы статьи настаивают, что проверка образцов, а\nвозможно и пациентов, на наличие вируса Усуту, должна стать рутинной процедурой.\nНесмотря на то, что вирус неопасен для здоровых людей, у людей с отягощающими\nфакторами, такими как возраст и наличие других заболеваний, инфекция может\nпривести к развитию неврологических симптомов. К тому же вирусы быстро\nмутируют, а рутинный мониторинг поможет держать ситуацию под контролем и не\nдопустить развития эпидемии в случае появления более опасной формы вируса. Именно\nтак началась эпидемия лихорадки Зика — мы рассказывали, что способность\nвируса Зика поражать клетки-предшественницы нейронов резко повысилась после\nвозникновения единственной мутации в его геноме. \nДарья Спасская\n \n \n\n\n'}}]

# %% [markdown]
# Если мы хотим найти все слова из запроса, к нему следует добавить параметр `operator`созначением `and`.

# %%
res = es.search(index="nplus1", body={"query": {"match": {"text": 
                                       {"query":"Франции Германии и", "operator": "and"}}}})
res["hits"]["hits"]
# Out:
# [{'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'ewW2FHABiLWAMI7vjS2r',
#   '_score': 5.4853954,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '14:57',
#    'rubrics': 'Физика',
#    'difficulty': '4.7',
#    'title': 'Физики научились управлять движением топологических дефектов в ионных цепочках',
#    'author': 'Александр Дубов',
#    'text': '\n\n\nДвижением топологических дефектов в кристаллических структурах, которые образуются из ионов в ионных ловушках, можно управлять, изменяя амплитуду внешнего воздействия. Такой эффект группа физиков из Германии и Франции продемонстрировала на зигзагообразных ионных цепочках, состоящих из 34 ионов магния. Результаты исследования опубликованы в Physical Review Letters.\nТопологические дефекты в кристалле — области периодической кристаллической структуры, на которых происходит нарушение симметрии кристалла и одна топологическая фаза сменяется на другую. В трехмерных кристаллах топологическими дефектами являются, например, дислокации (при нарушении симметрии самого кристалла) или скирмионы (при нарушении магнитной симметрии). Топологический дефект может двигаться по кристаллу, формируя солитон — единичную устойчивую волну. Для упорядоченных структур с низкой размерностью и небольшим объемом управление солитонами может оказаться полезным, например, для изменения конфигураций в молекулярных машинах или транспорта ионов через мембранные каналы.\nВ своей работе группа физиков из Германии исследовала кулоновский кристалл, состоящий из 34 ионов Mg+. Такой кристалл представляет из себя квазиодномерную зигзагообразную цепочку, которая имеет две эквивалентных зеркальных конфигурации. Этот кристалл ученые фиксировали в вакуумной ионной ловушке с помощью лазерного охлаждения. При этом конфигурацией цепочки можно управлять, изменяя параметры охлаждающего лазерного пучка, а за ее состоянием наблюдать с помощью флуоресцентной спектроскопии.Кроме того, ученые смогли показать, что если в одной половине кристалла стабилизировать одну из возможных конфигураций, а в другой — вторую, то образуется структура, в середине которой находится «излом» — топологический дефект, на котором происходит смена конформации.\n\n\n\n\n\n\n\n'}},
#  {'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'dAW2FHABiLWAMI7vjS0T',
#   '_score': 3.6001692,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '18:33',
#    'rubrics': 'Медицина',
#    'difficulty': '2.1',
#    'title': 'В донорской крови нашли африканский птичий вирус',
#    'author': 'Дарья Спасская',
#    'text': '\n\n\nАфриканский вирус Усуту, который с начала 2000-х годов вызвал\nв Европе несколько эпидемий среди птиц, встречается у людей чаще, чем\nожидалось. В частности, вирус был обнаружен в семи образцах донорской крови в\nавстрийском донорском центре. Об этом сообщает европейский эпидемиологический\nжурнал Eurosurveillance, а\nо распространении вируса среди птиц на территории Австрии и Венгрии авторы\nрассказали в журнале Emerging Microbes & Infections.\nВирус Усуту\nотносится к группе флавивирусов, так же как вирус энцефалита, лихорадки\nЗападного Нила, денге и вирус Зика. Как и многие представители этой группы,\nпереносится вирус Усуту комарами. Он был впервые описан на территории Африки в\n1959 году, а в 2001 году был зарегистрирован на территории Австрии, где вызвал\nэпидемию энцефалита среди дроздов. С 2003 по 2006 годы в Австрии также нередко\nвстречались случаи заражения диких птиц, однако потом болезнь пошла на спад,\nпо-видимому благодаря выработке иммунитета против вируса. С тех пор и по сей\nдень вспышки вирусной инфекции среди перелетных птиц регистрировали в разных\nстранах Европы, в том числе в Италии, Франции, Германии и других. \nОфициально случаи заражения\nвирусом Усуту людей были подтверждены лишь несколько раз — дважды в Африке, у\nпациентов с лихорадкой, а после в Италии в 2009 году. Два итальянских пациента\nс иммунодефицитом в результате заражения вирусом заболели энцефалитом. Однако,\nисследования, проведенные во время птичьих эпидемий, показали, что антитела\nпротив вируса встречаются у людей не так уж редко. Это означает, что люди регулярно\nзаражаются вирусом, но в подавляющем большинстве случаев инфекция проходит\nбессимптомно. \n В 2014 году австрийский Красный крест, который\nзанимается сбором донорской крови, начал тестировать поступающий к ним материал\nна наличие вируса лихорадки Западного Нила. Летом 2017 года в донорском центре\nбыло обнаружено семь образцов зараженной крови. Дальнейшая проверка не\nподтвердила принадлежность найденной вирусной РНК к искомому виду вируса, зато\nпрояснила, что образцы заражены вирусом Усуту. Как оказалось, все доноры не\nпроявляли никаких клинических симптомов. В тропические страны они не выезжали,\nто есть заразились вирусом на территории Австрии. \nКонечно, факт\nобнаружения неопасного вируса в донорской крови это еще не повод бить тревогу и\nобъявлять эпидемию, однако авторы статьи настаивают, что проверка образцов, а\nвозможно и пациентов, на наличие вируса Усуту, должна стать рутинной процедурой.\nНесмотря на то, что вирус неопасен для здоровых людей, у людей с отягощающими\nфакторами, такими как возраст и наличие других заболеваний, инфекция может\nпривести к развитию неврологических симптомов. К тому же вирусы быстро\nмутируют, а рутинный мониторинг поможет держать ситуацию под контролем и не\nдопустить развития эпидемии в случае появления более опасной формы вируса. Именно\nтак началась эпидемия лихорадки Зика — мы рассказывали, что способность\nвируса Зика поражать клетки-предшественницы нейронов резко повысилась после\nвозникновения единственной мутации в его геноме. \nДарья Спасская\n \n \n\n\n'}}]

# %% [markdown]
# Также можно задавать интервалы поиска при помощи ключевого слова `range`. `gte` и `lt` задают операторы "больше или равно" и "меньше".

# %%
res = es.search(index="nplus1", body={"query": {"range": {"time": 
                                       {"gte":"10:00", "lt": "12:00"}}}})
res["hits"]["hits"]
# Out:
# [{'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'ggW2FHABiLWAMI7vjS3t',
#   '_score': 1.0,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '11:39',
#    'rubrics': 'Энергетика',
#    'difficulty': '3.7',
#    'title': 'Исландцы заставили электростанцию улавливать углекислый газ',
#    'author': 'Василий Сычев',
#    'text': '\n\n\nИсландская энергетическая компания Reykjavik Energy совместно с швейцарской Climeworks провела модернизацию геотермальной электростанции Хедлисхейди около вулкана Хенгидль, установив на ней модули прямого улавливания диоксида углерода из воздуха. Как пишет Quartz, благодаря такому усовершенствованию исландская станция стала первой в мире электростанцией с отрицательным выбросом CO2.Выбросы углекислого газа считаются одной из нескольких возможных причин глобального потепления. Поэтому некоторые страны мира начали уделять внимание снижению уровня выброса CO2 в атмосферу. Это делается, в частности, поощрением граждан на использование электротранспорта, а также постепенным сокращением доли тепловых электростанций в энергетике.Электростанция Хедлисхейди благодаря модулям прямого улавливания диоксида углерода позволяет изымать из атмосферы до 50 тонн углекислого газа в год. Пока новая система работает в тестовом режиме. Стороны намерены оценить стоимость удаления углекислого газа из атмосферы и эффективность системы в целом.Модуль прямого улавливания углекислого газа работает по принципу его минерализации. Вентиляционная установка прогоняет через специальные пропитанные аминами фильтры атмосферный воздух. В фильтрах амины связывают углекислый газ. Затем они подвергаются нагреву от геотермального источника тепла, в результате чего диоксид углерода высвобождается.Свободный углекислый газ поступает в установку с водой, где растворяется в ней. На растворение одного килограмма углекислого газа необходимы 27 килограммов воды. После растворения уже газированная вода закачивается в базальтовые породы на глубине 700 метров, где со временем происходит реакция и превращение CO2 в твердый минерал.В компании Climeworks, разработавшей модуль прямого улавливания углекислого газа, утверждают, что такие системы можно установить на любой геотермальной электростанции, построенной на базальтовых породах. Работы на станции Хедлисхейди были проведены в рамках проекта CarbFix. Этот проект предусматривает удаление одного процента мировых выбросов CO2 в год к 2025 году.Исландская геотермальная электростанция Хедлисхейди использует подземные источники тепла для выработки электроэнергии. Она расположена в 25 километрах от Рейкьявика. Мощность исландской электростанции составляет 303 мегаватт. Кроме того, станция поставляет Рейкьявику 130 мегаватт тепла.В середине июля текущего года стало известно, что американская электростанция Sheldon в Небраске, до 1970-х годов проработавшая на атомном реакторе, будет переделана на сжигание газа для выработки электричества. В качестве топлива в электростанции будет использоваться водород. Благодаря такой переделке местные власти рассчитывают сделать электростанцию более экологичной.Мощность первой очереди электростанции составляет 105 мегаватт, а второй — 120 мегаватт. Согласно планам местных властей, переделке под работу на водороде будет подвергнута вторая очередь электростанции. После завершения работ Sheldon станет крупнейшей в США электростанцией, работающей на водороде.В ближайшее время планируется начать подготовку второй очереди электростанции к переделке. Саму конвертацию планируется завершить к 2020 году. В результате конвертации, как ожидается, станция станет экологичной — в настоящее время при сжигании угля второй очередью станции Sheldon выбрасывается около одного миллиона тонн углекислого газа в год.Электростанция была построена в 1958-1963 годах и состоит из двух очередей. До 1968 года электростанция работала на атомном реакторе, после чего ее постепенно перевели на сжигание газа. В 1974 году электростанцию снова переделали, доработав ее под сжигание каменного угля с пониженным содержанием серы. В таком виде она работает до сих пор.Василий Сычёв\n'}},
#  {'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'gwW2FHABiLWAMI7vjS32',
#   '_score': 1.0,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '11:20',
#    'rubrics': 'Археология',
#    'difficulty': '1.5',
#    'title': 'В захоронениях викингов нашли шелковые ткани с арабскими надписями',
#    'author': 'Екатерина Русакова',
#    'text': '\n\n\nШведские\nархеологи обнаружили на погребальных\nодеяниях викингов надписи на арабском\nязыке. На полосах шелка были вытканы\nслова «Аллах» и «Али». Ткани были найдены\nв могилах на территории крупного\nторгового города Бирка и в захоронениях\nс погребальными ладьями в Уппсале на\nюго-востоке Швеции. Об открытии сообщается\nв пресс-релизе Уппсальского университета.\nИсследователи\nреставрировали ткани, найденные в\nзахоронениях викингов, и готовили их\nдля выставки в музее города Энчепинга\nнедалеко от Уппсалы. Во время работы\nони обнаружили вытканные на полосках\nшелковой ткани надписи, сделанные\nкуфическим\nстилем. Это был один из старейших\nвидов арабского письма, который был\nразработан в конце VIII\nвека. Ученые расшифровали арабские\nслова «Аллах» и «Али». Под Али, возможно, имелся\nв виду двоюродный брат и зять пророка\nМухаммеда, Али\nибн Абу Талиб — его ближайший\nсподвижник, почитаемый мусульманами-суннитами\nи мусульманами-шиитами как праведный\nхалиф.\n\nПо\nсловам Анники Ларссон, занимающейся\nархеологией текстиля, слово «Аллах»\nбыло написано в зеркальном варианте.\nОбычно на арабском пишут справа налево.\n«...Возможно, это была попытка записать\nмолитвы так, чтобы их можно было читать\nслева направо, но арабским письмом. Мы\nчасто утверждаем, что артефакты с востока\nв захоронениях викингов попадали к ним\nтолько в результате грабежа или торговли.\nНо это объяснение не работает, так как\nарабские надписи появлялись на типичных\nпредметах гардероба викингов, которые\nвстречаются на изображениях валькирий»,\n— говорит Ларссон. \n\n\n\n\n\n\n\n\n'}},
#  {'_index': 'nplus1',
#   '_type': 'article',
#   '_id': 'hAW2FHABiLWAMI7vjS3-',
#   '_score': 1.0,
#   '_source': {'date': '16 Окт. 2017',
#    'time': '10:47',
#    'rubrics': 'Психология',
#    'difficulty': '4.7',
#    'title': 'Психоделики изменили активность мозга при депрессии',
#    'author': 'Елизавета Ивтушок',
#    'text': '\n\n\n\nПсиходелик псилоцибин может облегчить депрессивное состояние и улучшить активность головного мозга. Это выяснила международная команда ученых, которая провела клинические испытания психоделика в качестве лечения тяжелой формы депрессии. Статья опубликована в журнале Scientific Reports.Активным веществом галлюциногенных грибов, таких, например, как гриб псилоцибе (Psilocybe), является псилоцибин — вещество, структурно похожее на эндогенный нейротрансмиттер серотонин и выступающее агонистом (активатором) серотониновых рецепторов. Серотонин, в свою очередь, тесно связан с аффективными состояниями: нарушение функций серотонинергических путей приводит к возникновению различных психический расстройств, самое частое из которых — клиническая депрессия. Псилоцибин (в качестве дополнения к психотерапии) уже показал свою эффективность в лечении алкогольной и табачной зависимости, обсессивно-компульсивного расстройства, а также тяжелых форм клинической депрессии. Авторы новой работы применили психоделик в процессе лечения пациентов с депрессией с целью проследить за изменениями в активности их головного мозга и систематизировать данные об улучшении психического состояния при приеме препарата.В ходе эксперимента ученые проверили изменения двух параметров (мозгового кровообращения и активности головного мозга), используя метод фМРТ в состоянии покоя (англ. resting state fMRI). Измерения были проведены до приема психоделика, а также через день после двух приемов (10 и 25 миллиграммов) в течение одной недели. Всего в эксперименте приняли участие 19 пациентов с депрессией, из которых у 16 были получены изображения мозга. До эксперимента, через день и через пять недель после добровольцы также заполнили опросник, выявляющий их психическое состояние.Проведя анализ активности головного мозга в состоянии покоя, ученые выявили улучшение активности передней поясной коры — фронтальной части поясной коры, которая участвует в процессе формирования эмоций, а также в вентромедиальной части префронтальной коры, отвечающей за эмоциональный контроль. Кроме того, результаты эксперимента указывают на уменьшение активности парагиппокальной извилины: повышенная ее активность связана с проявлением тяжелой депрессии по результатам мета-анализа. Ученые также обнаружили уменьшение уровня циркуляции крови в миндалевидном теле — билатеральной структуре головного мозга, которая участвует в формировании негативных эмоций, таких как страх и отвращение, и повышенная активность которой также наблюдается при депрессивных состояниях.Результаты опросника на выявление синдромов депрессивного состояния показали, что через день после приема препарата среднее значение по шкале опросника (от 0 до 27, где максимальный балл соответствует проявлению тяжелой формы депрессии) снизилось на восемь баллов, а результаты сохранились к повторному измерению через пять недель.\n\n\n\n\n\n\n'}}]

# %% [markdown]
# ---

# %% [markdown]
# Теперь немного отвлечемся на замеры производительности ElasticSearch. Скорость ее работы с отдельными запросами оставляет желать лучшего - несколько десятков запросов в секунду. Гораздо лучше она работает при помощи потоковых запросов, отправляющих на запись сразу много документов.
#
# Заметим, что при параллельной отправке документов БД работает быстрее, но до миллиона запросов в секунду всё равно далеко. Для того, чтобы получить такую скорость необходим кластер.
#
# Попробуем положить в базу первый миллион сочетаний "существительное+прилагательное" из базы [КОСИКО](http://cosyco.ru/). Для этого создадим индекс и зададим тип документов.

# %%
es.indices.delete("cosyco")
es.indices.create(index = "cosyco")
mapit = {"combinations" : {"properties" : {"noun" : {"type" : "text", "analyzer" : "russian"},
                                           "adj"  : {"type" : "text", "analyzer" : "russian"},
                                           "frq"  : {"type": "integer"}}}}

es.indices.put_mapping(index = "cosyco", 
                       doc_type = 'combinations', 
                       body = mapit, 
                       include_type_name=True)
# Out:
# {'acknowledged': True}

# %% [markdown]
# Код ниже обеспечивает около 10 запросов в секунду - просто слезы.

# %%
fil = open("noun_adj_inf_combs.txt")
cntr = 0
for line in tqdm(fil):
    r = line.split(";")
    #r={"noun":r[0], "adj":r[1], "frq": r[2]}
    r = {"noun":r[0], "adj":r[1]}
    es.index(index="cosyco", doc_type='combinations', body=r)
    cntr += 1
    if cntr > 200:
        break
fil.close()
# Out:
# 200it [00:22,  9.12it/s]

# %% [markdown]
# Создадим функции, которые будут читать данные из файла и класть их в базу. Так как мы хотим повышенную производительность, класть будем по нескоклько тысяч документов за один раз.

# %%
def getCosycoLines(start, size):
    fil = open("noun_adj_inf_combs.txt")
    for i in range(start):
        _ = fil.readline()

    res=[]
    for i in range(size):
        r = fil.readline().split(";")
        #r={"noun":r[0], "adj":r[1], "frq": r[2]}
        r2 = { "index": {"_index": "cosyco", "_type": "combinations"} }
        res.append(r2)
        r2 = {"noun":r[0].strip(), "adj":r[1].strip()}
        res.append(r2)
        
    fil.close()
    return res

# %%
rrr = getCosycoLines(0, 1000000)

# %%
# %%time
#bulk(es, getCosycoLines(0, 1000000), index="cosyco", doc_type='combinations')
# Возвращает информацию об ошибках - кто был добавлен, а кто нет.
_ = es.bulk(rrr, index="cosyco", doc_type='combinations')
# Out:
# ---------------------------------------------------------------------------
# TransportError                            Traceback (most recent call last)
# <ipython-input-8-8bd0559b9071> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', '#bulk(es, getCosycoLines(0, 1000000), index="cosyco", doc_type=\'combinations\')\n# Возвращает информацию об ошибках - кто был добавлен, а кто нет.\n_ = es.bulk(rrr, index="cosyco", doc_type=\'combinations\')')
#
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/lib/python3/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/lib/python3/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#      82                 if p in kwargs:
#      83                     params[p] = kwargs.pop(p)
# ---> 84             return func(*args, params=params, **kwargs)
#      85
#      86         return _wrapped
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/client/__init__.py in bulk(self, body, index, doc_type, params)
#     447         body = _bulk_body(self.transport.serializer, body)
#     448         return self.transport.perform_request(
# --> 449             "POST", _make_path(index, doc_type, "_bulk"), params=params, body=body
#     450         )
#     451
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     356                     headers=headers,
#     357                     ignore=ignore,
# --> 358                     timeout=timeout,
#     359                 )
#     360
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     259                 method, full_url, url, body, duration, response.status, raw_data
#     260             )
# --> 261             self._raise_error(response.status, raw_data)
#     262
#     263         self.log_request_success(
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/connection/base.py in _raise_error(self, status_code, raw_data)
#     180
#     181         raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
# --> 182             status_code, error_message, additional_info
#     183         )
#     184
#
# TransportError: TransportError(413, '')

# %% [markdown]
# Код ниже занял около 5 секунд: 20000 записей в секунду. Не так много, но гораздо лучше, чем было.

# %%
# %%time

for i in tqdm(range(100)):
    passed=False
    while not passed:
        try:
            acq = es.bulk(getCosycoLines(i*10000, 10000), index="cosyco", doc_type='combinations')
            passed=True
        except:
            print(acq)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|          | 1/100 [00:00<00:54,  1.81it/s]
#   2%|▏         | 2/100 [00:01<00:55,  1.77it/s]
#   3%|▎         | 3/100 [00:03<01:36,  1.01it/s]
#   4%|▍         | 4/100 [00:04<01:58,  1.23s/it]
#   5%|▌         | 5/100 [00:05<01:37,  1.03s/it]
#   6%|▌         | 6/100 [00:06<01:23,  1.13it/s]
#   7%|▋         | 7/100 [00:06<01:13,  1.27it/s]
#   8%|▊         | 8/100 [00:07<01:07,  1.36it/s]
#   9%|▉         | 9/100 [00:07<01:03,  1.44it/s]
#  10%|█         | 10/100 [00:08<01:00,  1.50it/s]
#  11%|█         | 11/100 [00:09<00:57,  1.55it/s]
#  12%|█▏        | 12/100 [00:09<01:02,  1.41it/s]
#  13%|█▎        | 13/100 [00:10<00:58,  1.48it/s]
#  14%|█▍        | 14/100 [00:11<00:55,  1.54it/s]
#  15%|█▌        | 15/100 [00:11<00:54,  1.56it/s]
#  16%|█▌        | 16/100 [00:12<00:54,  1.55it/s]
#  17%|█▋        | 17/100 [00:13<00:57,  1.44it/s]
#  18%|█▊        | 18/100 [00:13<00:54,  1.50it/s]
#  19%|█▉        | 19/100 [00:14<00:52,  1.54it/s]
#  20%|██        | 20/100 [00:14<00:51,  1.55it/s]
#  21%|██        | 21/100 [00:15<00:56,  1.40it/s]
#  22%|██▏       | 22/100 [00:16<00:54,  1.42it/s]
#  23%|██▎       | 23/100 [00:17<00:52,  1.47it/s]
#  24%|██▍       | 24/100 [00:17<00:51,  1.49it/s]
#  25%|██▌       | 25/100 [00:18<00:49,  1.52it/s]
#  26%|██▌       | 26/100 [00:19<00:48,  1.54it/s]
#  27%|██▋       | 27/100 [00:19<00:47,  1.55it/s]
#  28%|██▊       | 28/100 [00:20<00:46,  1.56it/s]
#  29%|██▉       | 29/100 [00:21<00:45,  1.54it/s]
#  30%|███       | 30/100 [00:22<01:01,  1.14it/s]
#  31%|███       | 31/100 [00:23<01:08,  1.00it/s]
#  32%|███▏      | 32/100 [00:24<01:00,  1.12it/s]
#  33%|███▎      | 33/100 [00:25<00:55,  1.21it/s]
#  34%|███▍      | 34/100 [00:25<00:54,  1.22it/s]
#  35%|███▌      | 35/100 [00:26<00:51,  1.26it/s]
#  36%|███▌      | 36/100 [00:27<00:48,  1.32it/s]
#  37%|███▋      | 37/100 [00:27<00:46,  1.34it/s]
#  38%|███▊      | 38/100 [00:29<00:53,  1.16it/s]
#  39%|███▉      | 39/100 [00:30<00:54,  1.11it/s]
#  40%|████      | 40/100 [00:30<00:50,  1.19it/s]
#  41%|████      | 41/100 [00:31<00:47,  1.25it/s]
#  42%|████▏     | 42/100 [00:32<00:44,  1.29it/s]
#  43%|████▎     | 43/100 [00:32<00:43,  1.33it/s]
#  44%|████▍     | 44/100 [00:33<00:41,  1.34it/s]
#  45%|████▌     | 45/100 [00:34<00:40,  1.37it/s]
#  46%|████▌     | 46/100 [00:35<00:45,  1.20it/s]
#  47%|████▋     | 47/100 [00:36<00:42,  1.25it/s]
#  48%|████▊     | 48/100 [00:37<00:44,  1.16it/s]
#  49%|████▉     | 49/100 [00:37<00:42,  1.20it/s]
#  50%|█████     | 50/100 [00:38<00:40,  1.24it/s]
#  51%|█████     | 51/100 [00:39<00:42,  1.14it/s]
#  52%|█████▏    | 52/100 [00:40<00:39,  1.22it/s]
#  53%|█████▎    | 53/100 [00:41<00:37,  1.26it/s]
#  54%|█████▍    | 54/100 [00:41<00:36,  1.27it/s]
#  55%|█████▌    | 55/100 [00:43<00:49,  1.10s/it]
#  56%|█████▌    | 56/100 [00:45<00:57,  1.30s/it]
#  57%|█████▋    | 57/100 [00:47<01:10,  1.64s/it]
#  58%|█████▊    | 58/100 [00:49<01:11,  1.70s/it]
#  59%|█████▉    | 59/100 [00:51<01:15,  1.84s/it]
#  60%|██████    | 60/100 [00:53<01:11,  1.79s/it]
#  61%|██████    | 61/100 [00:55<01:12,  1.86s/it]
#  62%|██████▏   | 62/100 [00:57<01:08,  1.81s/it]
#  63%|██████▎   | 63/100 [00:59<01:11,  1.92s/it]
#  64%|██████▍   | 64/100 [01:00<00:56,  1.57s/it]
#  65%|██████▌   | 65/100 [01:00<00:46,  1.32s/it]
#  66%|██████▌   | 66/100 [01:01<00:41,  1.23s/it]
#  67%|██████▋   | 67/100 [01:02<00:35,  1.07s/it]
#  68%|██████▊   | 68/100 [01:03<00:31,  1.03it/s]
#  69%|██████▉   | 69/100 [01:04<00:27,  1.11it/s]
#  70%|███████   | 70/100 [01:04<00:25,  1.17it/s]
#  71%|███████   | 71/100 [01:05<00:24,  1.20it/s]
#  72%|███████▏  | 72/100 [01:07<00:28,  1.03s/it]
#  73%|███████▎  | 73/100 [01:08<00:33,  1.25s/it]
#  74%|███████▍  | 74/100 [01:10<00:36,  1.40s/it]
#  75%|███████▌  | 75/100 [01:12<00:40,  1.63s/it]
#  76%|███████▌  | 76/100 [01:13<00:32,  1.37s/it]
#  77%|███████▋  | 77/100 [01:15<00:34,  1.48s/it]
#  78%|███████▊  | 78/100 [01:16<00:27,  1.26s/it]
#  79%|███████▉  | 79/100 [01:16<00:23,  1.13s/it]
#  80%|████████  | 80/100 [01:19<00:29,  1.46s/it]
#  81%|████████  | 81/100 [01:19<00:23,  1.25s/it]
#  82%|████████▏ | 82/100 [01:20<00:20,  1.13s/it]
#  83%|████████▎ | 83/100 [01:22<00:23,  1.41s/it]
#  84%|████████▍ | 84/100 [01:24<00:25,  1.59s/it]
#  85%|████████▌ | 85/100 [01:26<00:22,  1.53s/it]
#  86%|████████▌ | 86/100 [01:27<00:22,  1.58s/it]
#  87%|████████▋ | 87/100 [01:30<00:22,  1.76s/it]
#  88%|████████▊ | 88/100 [01:30<00:17,  1.47s/it]
#  89%|████████▉ | 89/100 [01:31<00:14,  1.30s/it]
#  90%|█████████ | 90/100 [01:32<00:12,  1.23s/it]
#  91%|█████████ | 91/100 [01:33<00:09,  1.11s/it]
#  92%|█████████▏| 92/100 [01:34<00:08,  1.04s/it]
#  93%|█████████▎| 93/100 [01:37<00:10,  1.49s/it]
#  94%|█████████▍| 94/100 [01:37<00:07,  1.31s/it]
#  95%|█████████▌| 95/100 [01:38<00:05,  1.19s/it]
#  96%|█████████▌| 96/100 [01:39<00:04,  1.08s/it]
#  97%|█████████▋| 97/100 [01:40<00:03,  1.11s/it]
#  98%|█████████▊| 98/100 [01:41<00:02,  1.04s/it]
#  99%|█████████▉| 99/100 [01:42<00:01,  1.00s/it]
# 100%|██████████| 100/100 [01:43<00:00,  1.04s/it]
# CPU times: user 44.6 s, sys: 1.01 s, total: 45.6 s
# Wall time: 1min 43s

# %%
'Ё' < 'А'
# Out:
# True

# %% [markdown]
# Посмотрим как со скоростью поиска.

# %%
# %%time
res = es.search(index="cosyco", body={"query": {"match_all": {}}})
res
# Out:
# CPU times: user 464 µs, sys: 3.93 ms, total: 4.39 ms
# Wall time: 2.67 s

# %%
# %%time
res = es.search(index="cosyco", body={"query": {"match": {"adj":"БЕЛЫЙ"}}})
print(res)
# Out:
# {'took': 4, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 839, 'relation': 'eq'}, 'max_score': 7.082705, 'hits': [{'_index': 'cosyco', '_type': 'combinations', '_id': 'bNZHEnABtPFlvM7f_trQ', '_score': 7.082705, '_source': {'noun': 'АВТОМОБИЛЬЧИК', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': '-9ZHEnABtPFlvM7f_tzQ', '_score': 7.082705, '_source': {'noun': 'АВТОМОТРИСА', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'ldZHEnABtPFlvM7f_uPR', '_score': 7.082705, '_source': {'noun': 'АВТООТВЕТЧИК', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'ZNZHEnABtPFlvM7f_unR', '_score': 7.082705, '_source': {'noun': 'АВТОПОКРЫШКА', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'tNZHEnABtPFlvM7f_unR', '_score': 7.082705, '_source': {'noun': 'АВТОПОРТРЕТ', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'TNZHEnABtPFlvM7f_uzR', '_score': 7.082705, '_source': {'noun': 'АВТОПРИЦЕП', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'qdZHEnABtPFlvM7f_uzR', '_score': 7.082705, '_source': {'noun': 'АВТОПРОБЕГ', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'e9ZHEnABtPFlvM7f_vDR', '_score': 7.082705, '_source': {'noun': 'АВТОР', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'RtZIEnABtPFlvM7fAf8o', '_score': 7.082705, '_source': {'noun': 'АВТОРИТАРИЗМ', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': '4NdIEnABtPFlvM7fAQEo', '_score': 7.082705, '_source': {'noun': 'АВТОРИТЕТ', 'adj': 'БЕЛЫЙ'}}]}}
# CPU times: user 3.24 ms, sys: 83 µs, total: 3.32 ms
# Wall time: 7.28 ms

# %% [markdown]
# 10 миллисекунд при поиске в миллионе документов - очень неплохо.
#
# Хотя если вытаскивать все документы... Для этого надо добавить поле `size`.

# %%
# %%time
res = es.search(index="cosyco", body={"size":1000, "query": {"match": {"adj":"белый"}}})
print(res)
# Out:
# {'took': 43, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 839, 'relation': 'eq'}, 'max_score': 7.082705, 'hits': [{'_index': 'cosyco', '_type': 'combinations', '_id': 'bNZHEnABtPFlvM7f_trQ', '_score': 7.082705, '_source': {'noun': 'АВТОМОБИЛЬЧИК', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': '-9ZHEnABtPFlvM7f_tzQ', '_score': 7.082705, '_source': {'noun': 'АВТОМОТРИСА', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'ldZHEnABtPFlvM7f_uPR', '_score': 7.082705, '_source': {'noun': 'АВТООТВЕТЧИК', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'ZNZHEnABtPFlvM7f_unR', '_score': 7.082705, '_source': {'noun': 'АВТОПОКРЫШКА', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'tNZHEnABtPFlvM7f_unR', '_score': 7.082705, '_source': {'noun': 'АВТОПОРТРЕТ', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'TNZHEnABtPFlvM7f_uzR', '_score': 7.082705, '_source': {'noun': 'АВТОПРИЦЕП', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'qdZHEnABtPFlvM7f_uzR', '_score': 7.082705, '_source': {'noun': 'АВТОПРОБЕГ', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'e9ZHEnABtPFlvM7f_vDR', '_score': 7.082705, '_source': {'noun': 'АВТОР', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'RtZIEnABtPFlvM7fAf8o', '_score': 7.082705, '_source': {'noun': 'АВТОРИТАРИЗМ', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': '4NdIEnABtPFlvM7fAQEo', '_score': 7.082705, '_source': {'noun': 'АВТОРИТЕТ', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'yNdIEnABtPFlvM7fAQ0o', '_score': 7.082705, '_source': {'noun': 'АВТОРУЧКА', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'NNdIEnABtPFlvM7fARMp', '_score': 7.082705, '_source': {'noun': 'АВТОСТАНЦИЯ', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'bNdIEnABtPFlvM7fARQp', '_score': 7.082705, '_source': {'noun': 'АВТОСТОЯНКА', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'eNdIEnABtPFlvM7fARYp', '_score': 7.082705, '_source': {'noun': 'АВТОСТРАДА', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'sddIEnABtPFlvM7fARwp', '_score': 7.082705, '_source': {'noun': 'АВТОФОКУС', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'LNdIEnABtPFlvM7fAR0p', '_score': 7.082705, '_source': {'noun': 'АВТОФУРГОН', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'atdIEnABtPFlvM7fAR8p', '_score': 7.082705, '_source': {'noun': 'АВТОЦИСТЕРНА', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': '4tdIEnABtPFlvM7fC5ij', '_score': 7.082705, '_source': {'noun': 'АДАПТЕР', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'CddIEnABtPFlvM7fC52j', '_score': 7.082705, '_source': {'noun': 'АДВОКАТ', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'o9dIEnABtPFlvM7fC6aj', '_score': 7.082705, '_source': {'noun': 'АДВОКАТУРА', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': '09dIEnABtPFlvM7fC6qk', '_score': 7.082705, '_source': {'noun': 'АДЕЛИНА', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'H9dIEnABtPFlvM7fC6uk', '_score': 7.082705, '_source': {'noun': 'АДЕЛЬ', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'ItdIEnABtPFlvM7fC62k', '_score': 7.082705, '_source': {'noun': 'АДЕПТ', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'PtdIEnABtPFlvM7fC7Kk', '_score': 7.082705, '_source': {'noun': 'АДИАНТУМ', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'rtdIEnABtPFlvM7fC7Ok', '_score': 7.082705, '_source': {'noun': 'АДМИНИСТРАТОР', 'adj': 'БЕЛЫЙ'}}, {'_index': 'cosyco', '_type': 'combinations', '_id': 'wtdIEnABtPFlvM7fC7ul', '_score': 7.082705, '_s ...
# CPU times: user 10.7 ms, sys: 62 µs, total: 10.8 ms
# Wall time: 74 ms

# %% [markdown]
# 20-400 миллисекунд, время зависит от того, насколько БД подгрузила кэш и чем она занята еще.
#
# Ну, неплохо.

# %% [markdown]
# ---

# %% [markdown]
# Попробуем решить еще одну задачу. Возьмем Синтагрус из [Universal Dependencies](https://universaldependencies.org/). Загрузим из него пары слов, связанных синтаксическими отношениями. При этом будем различать расположение главного и зависимого слова - главное справа (->) или главное слева (<-). Далее организуем поиск по этим отношениям, показывая примеры интересующих нас отношений.
#
# Для этого нам придется завести два индекса. В первом будут хранится предложения, во втором - отношения между словами.
#
# **NB**
#
# Вроде бы в одном индексе можно хранить несколько типов документов. Но у меня почему-то не получитлось. Заодно не полчилось организовать хранение потомков и родителей как поддокументов в документе (точнее организовать по ним поиск). Поэтому решение несколько странное.

# %%
es=Elasticsearch()

# %% [markdown]
# Так как мы будем проводить аггрегацию по некоторым текстовым полям, то мы добавили к ним `"fielddata": True`.

# %%
#es.indices.delete("syntagrus")
#es.indices.delete("syntagrus_rel")

es.indices.create(index = "syntagrus")
mapit = {"sentences" : {"properties" : {"sentID" : {"type" : "integer"},
                                        "wordPos" : {"type" : "integer"},
                                        "token" : {"type" : "text", "analyzer" : "russian", "fielddata": True},
                                        "lemma" : {"type" : "text", "analyzer" : "russian", "fielddata": True},
                                        "PoS" : {"type" : "keyword"},
                                        "tag" : {"type" : "keyword"},
                                        "parent" : {"type" : "integer"},
                                        "conn" : {"type" : "text", "fielddata": True}}},
      
         
        }

es.indices.put_mapping(index = "syntagrus", 
                       doc_type = 'sentences', 
                       body = mapit, 
                       include_tupe_name=True)

es.indices.create(index = "syntagrus_rel")
mapit = {"relations" : {"properties" : {"sentID" : {"type" : "integer"},
                                        "conn" : {"type" : "keyword"},
                                        "dir" : {"type" : "keyword"},
                                        "child_PoS" : {"type" : "keyword"},
                                        "parent_PoS" : {"type" : "keyword"},
                                        "parent":{"type": "object", "properties": {
                                        "wordPos" : {"type" : "integer"},
                                        "token" : {"type" : "text", "analyzer" : "russian", "fielddata": True},
                                        "lemma" : {"type" : "text", "analyzer" : "russian", "fielddata": True},
                                        "PoS" : {"type" : "keyword"},
                                        "tag" : {"type" : "keyword"}
                                        }},
                                        "parent":{"type": "object", "properties": {
                                        "wordPos" : {"type" : "integer"},
                                        "token" : {"type" : "text", "analyzer" : "russian", "fielddata": True},
                                        "lemma" : {"type" : "text", "analyzer" : "russian", "fielddata": True},
                                        "PoS" : {"type" : "keyword"},
                                        "tag" : {"type" : "keyword"}
                                        }}}
                       }}
es.indices.put_mapping(index = "syntagrus_rel", 
                       doc_type = 'relations', 
                       body = mapit, 
                       include_tupe_name=True)

# %% [markdown]
# Читаем все тексты построчно.

# %%
with open("./ru_syntagrus-ud-dev.conllu") as infile:  
    lines=infile.readlines()

# %% [markdown]
# Напишем несколько функций: выделяющую предложения из текстов и помещающую данные в индексы.

# %%
def readSentence(lines, pos):
    #print("pos=",pos, "line=", lines[pos])
    sent=[]
    while pos<len(lines) and lines[pos]!="\n":
        if lines[pos][0]!='\n' and lines[pos][0]!='#':
            sent.append(lines[pos][:-2].split("\t"))
        pos+=1
    pos+=1
    return sent, pos
    
def putSentence(es, sent, sent_no):
    data=[]
    rels=[]
    for word in sent:
        if '.' in word[0]:
            continue
        data.append({"sentID" : sent_no,
              "wordPos" : word[0],
              "token" : word[1],
              "lemma" : word[2],
              "PoS" : word[3],
              "tag" : word[5],
              "parent" : word[6],
              "conn" : word[7]})
        rels.append({"sentID" : sent_no,
                     "conn" : word[7],
                     "dir" : '->' if word[0]<sent[int(word[6])][0] else '<-',
                     "child_PoS" : word[3],
                     "parent_PoS" : sent[int(word[6])][3],
                     "child":{"properties": {
                         "wordPos" : word[0],
                         "token" : word[1],
                         "lemma" : word[2],
                         "PoS" : word[3],
                         "tag" : word[5]
                     }},
                     "parent":{"properties": {
                         "wordPos" : sent[int(word[6])][0],
                         "token" : sent[int(word[6])][1],
                         "lemma" : sent[int(word[6])][2],
                         "PoS" : sent[int(word[6])][3],
                         "tag" : sent[int(word[6])][5]
                     }}}
        )
        
        #es.index(index="syntagrus", doc_type="sentences", body=data)
        
    bulk(es, rels, index="syntagrus_rel", doc_type='relations')        
    bulk(es, data, index="syntagrus", doc_type='sentences')

# %% [markdown]
# Помещаем данные в индексы. Получается несколько предложений в секунду.
#
# В примере ниже есть первая аггрегация. Чтобы ее задать используются ключевые слова `aggs` или `aggregations`. `"size": 0` необходимо, так как если его не задать, то помимо агрегированной информации будут выдаваться еще и документы, по которым проводилась агрегация.

# %%
res=es.search(index = "syntagrus", body = {"size": 0, "aggs": {"max_id": {"max": {"field": "sentID" }}}})
# Получение максимального номера предложения, уже хранимого в базе.
sent_no=res["aggregations"]["max_id"]["value"]
sent_no=1 if sent_no==None else sent_no+1
sent_no=int(sent_no)

# Пошли по всему файлу. 
pos=0
while pos<len(lines):
    sent, pos=readSentence(lines, pos)
    try:
        putSentence(es, sent, sent_no)
    except:
        pass
    sent_no+=1
    print(sent_no, end="\r")

# %% [markdown]
# Теперь посмотрим сколько есть "правых" и "левых" связей. Для этого зададим название поля для агрегации - dirs, поиск будет вестись по терминам - terms, поле поиска - "field" : "dir", сортировка по ключевому слову: "order": {"_term": "asc"}, выдать первые 100 ключевых слов: "size":"100" (по умолчанию - 10).
#
# **NB**
# У меня в параллель идет загрузка данных, так что числа будут несколько отличаться от запроса к запросу.

# %%
req={
    "size":0,
    "aggs" : {
        "dirs": {"terms" : { "field" : "dir", "size":"100", "order": {"_term": "asc"} }}
    }
}
es.search(index = "syntagrus_rel", body = req)
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'aggregations': {'dirs': {'buckets': [{'doc_count': 40974, 'key': '->'},
#     {'doc_count': 29490, 'key': '<-'}],
#    'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0}},
#  'hits': {'hits': [], 'max_score': 0.0, 'total': 70464},
#  'timed_out': False,
#  'took': 10}

# %% [markdown]
# Как видим, левого ветвления в русском языке больше. Но это ничего не значит. Посмотрим теперь зависимость от части речи главного и зависимого слов. Так как используется вложенная агрегация, то внутри одной мы вставляем другую: внутри агрегации "p_poses" будет агрегация "ch_poses", а в ней - "dirs".

# %%
req={
    "size":0,
    "aggs" : {
        "p_poses" : {
            "terms" : { "field" : "parent_PoS", "size":"100", "order": {"_term": "asc"}}, 
            "aggs" : {
                      "ch_poses" : {
                                    "terms" : { "field" : "child_PoS", "size":100, "order": {"_term": "asc"}}, 
                                    "aggs" : {
                                                "dirs": {"terms" : { "field" : "dir", "size":100, "order": {"_term": "asc"} }}
                                    }
                        }
                
            }
            
        }
    }
}
es.search(index = "syntagrus_rel", body = req)
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'aggregations': {'p_poses': {'buckets': [{'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 151,
#            'key': '->'},
#           {'doc_count': 303, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 454,
#         'key': 'ADJ'},
#        {'dirs': {'buckets': [{'doc_count': 83, 'key': '->'},
#           {'doc_count': 3, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 86,
#         'key': 'ADP'},
#        {'dirs': {'buckets': [{'doc_count': 454, 'key': '->'},
#           {'doc_count': 53, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 507,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 122, 'key': '->'},
#           {'doc_count': 46, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 168,
#         'key': 'AUX'},
#        {'dirs': {'buckets': [{'doc_count': 306, 'key': '->'},
#           {'doc_count': 27, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 333,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 30, 'key': '->'},
#           {'doc_count': 13, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 43,
#         'key': 'DET'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'INTJ'},
#        {'dirs': {'buckets': [{'doc_count': 349, 'key': '->'},
#           {'doc_count': 342, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 691,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 8, 'key': '->'},
#           {'doc_count': 4, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 12,
#         'key': 'NUM'},
#        {'dirs': {'buckets': [{'doc_count': 154, 'key': '->'},
#           {'doc_count': 28, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 182,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 201, 'key': '->'},
#           {'doc_count': 71, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 272,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 21, 'key': '->'},
#           {'doc_count': 22, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 43,
#         'key': 'PROPN'},
#        {'dirs': {'buckets': [{'doc_count': 716, 'key': '->'},
#           {'doc_count': 462, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1178,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 89, 'key': '->'},
#           {'doc_count': 24, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 113,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 139, 'key': '->'},
#           {'doc_count': 334, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 473,
#         'key': 'VERB'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 4557,
#      'key': 'ADJ'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 25,
#            'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 25,
#         'key': 'ADJ'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 77, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 78,
#         'key': 'ADP'},
#        {'dirs': {'buckets': [{'doc_count': 4, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 5,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 5, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 5,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 17, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 17,
#         'key': 'DET'},
#        {'dirs': {'buckets': [{'doc_count': 5, 'key': '->'},
#           {'doc_count': 205, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 210,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'NUM'},
#        {'dirs': {'buckets': [{'doc_count': 5, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 5,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 16, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 17,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 4, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 4,
#         'key': 'PROPN'},
#        {'dirs': {'buckets': [{'doc_count': 31, 'key': '->'},
#           {'doc_count': 25, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 56,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 5, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 5,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '->'},
#           {'doc_count': 4, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 6,
#         'key': 'VERB'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 434,
#      'key': 'ADP'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 10,
#            'key': '->'},
#           {'doc_count': 22, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 32,
#         'key': 'ADJ'},
#        {'dirs': {'buckets': [{'doc_count': 5, 'key': '->'},
#           {'doc_count': 19, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 24,
#         'key': 'ADP'},
#        {'dirs': {'buckets': [{'doc_count': 192, 'key': '->'},
#           {'doc_count': 106, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 298,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 10, 'key': '->'},
#           {'doc_count': 24, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 34,
#         'key': 'AUX'},
#        {'dirs': {'buckets': [{'doc_count': 117, 'key': '->'},
#           {'doc_count': 8, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 125,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'DET'},
#        {'dirs': {'buckets': [{'doc_count': 83, 'key': '->'},
#           {'doc_count': 179, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 262,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 3,
#         'key': 'NUM'},
#        {'dirs': {'buckets': [{'doc_count': 117, 'key': '->'},
#           {'doc_count': 118, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 235,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 37, 'key': '->'},
#           {'doc_count': 53, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 90,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 8, 'key': '->'},
#           {'doc_count': 14, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 22,
#         'key': 'PROPN'},
#        {'dirs': {'buckets': [{'doc_count': 397, 'key': '->'},
#           {'doc_count': 537, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 934,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 33, 'key': '->'},
#           {'doc_count': 68, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 101,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'SYM'},
#        {'dirs': {'buckets': [{'doc_count': 68, 'key': '->'},
#           {'doc_count': 230, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 298,
#         'key': 'VERB'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 2461,
#      'key': 'ADV'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 2,
#            'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'AUX'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 3,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 5, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 6,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'VERB'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 15,
#      'key': 'AUX'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 2,
#            'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 3,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 12, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 12,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 11, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 12,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 4, 'key': '->'},
#           {'doc_count': 37, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 41,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 5, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 5,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'PROPN'},
#        {'dirs': {'buckets': [{'doc_count': 6, 'key': '->'},
#           {'doc_count': 8, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 14,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'VERB'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 92,
#      'key': 'CCONJ'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 9,
#            'key': '->'},
#           {'doc_count': 37, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 46,
#         'key': 'ADJ'},
#        {'dirs': {'buckets': [{'doc_count': 21, 'key': '->'},
#           {'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 23,
#         'key': 'ADP'},
#        {'dirs': {'buckets': [{'doc_count': 28, 'key': '->'},
#           {'doc_count': 5, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 33,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'AUX'},
#        {'dirs': {'buckets': [{'doc_count': 20, 'key': '->'},
#           {'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 22,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 6, 'key': '->'},
#           {'doc_count': 13, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 19,
#         'key': 'DET'},
#        {'dirs': {'buckets': [{'doc_count': 15, 'key': '->'},
#           {'doc_count': 23, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 38,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'NUM'},
#        {'dirs': {'buckets': [{'doc_count': 24, 'key': '->'},
#           {'doc_count': 55, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 79,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 3, 'key': '->'},
#           {'doc_count': 6, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 9,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 7, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 7,
#         'key': 'PROPN'},
#        {'dirs': {'buckets': [{'doc_count': 35, 'key': '->'},
#           {'doc_count': 23, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 58,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 3,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 8, 'key': '->'},
#           {'doc_count': 34, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 42,
#         'key': 'VERB'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 382,
#      'key': 'DET'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 1,
#            'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '->'},
#           {'doc_count': 11, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 13,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'VERB'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 16,
#      'key': 'INTJ'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 4801,
#            'key': '->'},
#           {'doc_count': 437, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 5238,
#         'key': 'ADJ'},
#        {'dirs': {'buckets': [{'doc_count': 4767, 'key': '->'},
#           {'doc_count': 387, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 5154,
#         'key': 'ADP'},
#        {'dirs': {'buckets': [{'doc_count': 282, 'key': '->'},
#           {'doc_count': 118, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 400,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 65, 'key': '->'},
#           {'doc_count': 23, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 88,
#         'key': 'AUX'},
#        {'dirs': {'buckets': [{'doc_count': 791, 'key': '->'},
#           {'doc_count': 74, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 865,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 1444, 'key': '->'},
#           {'doc_count': 131, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1575,
#         'key': 'DET'},
#        {'dirs': {'buckets': [{'doc_count': 3, 'key': '->'},
#           {'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 5,
#         'key': 'INTJ'},
#        {'dirs': {'buckets': [{'doc_count': 1036, 'key': '->'},
#           {'doc_count': 5441, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 6477,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 581, 'key': '->'},
#           {'doc_count': 98, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 679,
#         'key': 'NUM'},
#        {'dirs': {'buckets': [{'doc_count': 316, 'key': '->'},
#           {'doc_count': 44, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 360,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 228, 'key': '->'},
#           {'doc_count': 120, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 348,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 130, 'key': '->'},
#           {'doc_count': 657, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 787,
#         'key': 'PROPN'},
#        {'dirs': {'buckets': [{'doc_count': 1703, 'key': '->'},
#           {'doc_count': 1247, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2950,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 174, 'key': '->'},
#           {'doc_count': 29, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 203,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 5, 'key': '->'},
#           {'doc_count': 7, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 12,
#         'key': 'SYM'},
#        {'dirs': {'buckets': [{'doc_count': 636, 'key': '->'},
#           {'doc_count': 726, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1362,
#         'key': 'VERB'},
#        {'dirs': {'buckets': [{'doc_count': 33, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 33,
#         'key': 'X'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 26536,
#      'key': 'NOUN'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 11,
#            'key': '->'},
#           {'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 13,
#         'key': 'ADJ'},
#        {'dirs': {'buckets': [{'doc_count': 40, 'key': '->'},
#           {'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 42,
#         'key': 'ADP'},
#        {'dirs': {'buckets': [{'doc_count': 37, 'key': '->'},
#           {'doc_count': 8, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 45,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 9, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 10,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 3, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 4,
#         'key': 'DET'},
#        {'dirs': {'buckets': [{'doc_count': 29, 'key': '->'},
#           {'doc_count': 102, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 131,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 14, 'key': '->'},
#           {'doc_count': 43, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 57,
#         'key': 'NUM'},
#        {'dirs': {'buckets': [{'doc_count': 29, 'key': '->'},
#           {'doc_count': 3, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 32,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 3, 'key': '->'},
#           {'doc_count': 5, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 8,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 3,
#         'key': 'PROPN'},
#        {'dirs': {'buckets': [{'doc_count': 74, 'key': '->'},
#           {'doc_count': 38, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 112,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 6, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 7,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'SYM'},
#        {'dirs': {'buckets': [{'doc_count': 3, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 4,
#         'key': 'VERB'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 469,
#      'key': 'NUM'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 2,
#            'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'ADJ'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'ADP'},
#        {'dirs': {'buckets': [{'doc_count': 29, 'key': '->'},
#           {'doc_count': 7, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 36,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 10, 'key': '->'},
#           {'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 12,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'DET'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'INTJ'},
#        {'dirs': {'buckets': [{'doc_count': 7, 'key': '->'},
#           {'doc_count': 13, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 20,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'NUM'},
#        {'dirs': {'buckets': [{'doc_count': 50, 'key': '->'},
#           {'doc_count': 43, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 93,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 7, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 8,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 4, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 4,
#         'key': 'PROPN'},
#        {'dirs': {'buckets': [{'doc_count': 26, 'key': '->'},
#           {'doc_count': 46, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 72,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '->'},
#           {'doc_count': 9, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 11,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 4, 'key': '->'},
#           {'doc_count': 6, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 10,
#         'key': 'VERB'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 275,
#      'key': 'PART'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 18,
#            'key': '->'},
#           {'doc_count': 61, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 79,
#         'key': 'ADJ'},
#        {'dirs': {'buckets': [{'doc_count': 676, 'key': '->'},
#           {'doc_count': 37, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 713,
#         'key': 'ADP'},
#        {'dirs': {'buckets': [{'doc_count': 43, 'key': '->'},
#           {'doc_count': 26, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 69,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 6, 'key': '->'},
#           {'doc_count': 3, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 9,
#         'key': 'AUX'},
#        {'dirs': {'buckets': [{'doc_count': 33, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 33,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 17, 'key': '->'},
#           {'doc_count': 14, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 31,
#         'key': 'DET'},
#        {'dirs': {'buckets': [{'doc_count': 55, 'key': '->'},
#           {'doc_count': 77, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 132,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 3, 'key': '->'},
#           {'doc_count': 3, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 6,
#         'key': 'NUM'},
#        {'dirs': {'buckets': [{'doc_count': 70, 'key': '->'},
#           {'doc_count': 60, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 130,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 16, 'key': '->'},
#           {'doc_count': 24, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 40,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 3, 'key': '->'},
#           {'doc_count': 4, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 7,
#         'key': 'PROPN'},
#        {'dirs': {'buckets': [{'doc_count': 132, 'key': '->'},
#           {'doc_count': 107, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 239,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 14, 'key': '->'},
#           {'doc_count': 3, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 17,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 80, 'key': '->'},
#           {'doc_count': 129, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 209,
#         'key': 'VERB'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 1714,
#      'key': 'PRON'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 56,
#            'key': '->'},
#           {'doc_count': 6, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 62,
#         'key': 'ADJ'},
#        {'dirs': {'buckets': [{'doc_count': 374, 'key': '->'},
#           {'doc_count': 21, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 395,
#         'key': 'ADP'},
#        {'dirs': {'buckets': [{'doc_count': 13, 'key': '->'},
#           {'doc_count': 7, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 20,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 7, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 7,
#         'key': 'AUX'},
#        {'dirs': {'buckets': [{'doc_count': 51, 'key': '->'},
#           {'doc_count': 5, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 56,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 12, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 12,
#         'key': 'DET'},
#        {'dirs': {'buckets': [{'doc_count': 26, 'key': '->'},
#           {'doc_count': 131, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 157,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 5, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 5,
#         'key': 'NUM'},
#        {'dirs': {'buckets': [{'doc_count': 21, 'key': '->'},
#           {'doc_count': 4, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 25,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 8, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 9,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 49, 'key': '->'},
#           {'doc_count': 435, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 484,
#         'key': 'PROPN'},
#        {'dirs': {'buckets': [{'doc_count': 205, 'key': '->'},
#           {'doc_count': 129, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 334,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 11, 'key': '->'},
#           {'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 13,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 24, 'key': '->'},
#           {'doc_count': 24, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 48,
#         'key': 'VERB'},
#        {'dirs': {'buckets': [{'doc_count': 5, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 5,
#         'key': 'X'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 1632,
#      'key': 'PROPN'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 214,
#            'key': '->'},
#           {'doc_count': 212, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 426,
#         'key': 'ADJ'},
#        {'dirs': {'buckets': [{'doc_count': 125, 'key': '->'},
#           {'doc_count': 72, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 197,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 3, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 4,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 3, 'key': '->'},
#           {'doc_count': 5, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 8,
#         'key': 'DET'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'INTJ'},
#        {'dirs': {'buckets': [{'doc_count': 273, 'key': '->'},
#           {'doc_count': 188, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 461,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 8, 'key': '->'},
#           {'doc_count': 9, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 17,
#         'key': 'NUM'},
#        {'dirs': {'buckets': [{'doc_count': 11, 'key': '->'},
#           {'doc_count': 3, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 14,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 26, 'key': '->'},
#           {'doc_count': 44, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 70,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 25, 'key': '->'},
#           {'doc_count': 11, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 36,
#         'key': 'PROPN'},
#        {'dirs': {'buckets': [{'doc_count': 4, 'key': '->'},
#           {'doc_count': 50, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 54,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 1365, 'key': '->'},
#           {'doc_count': 1523, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2888,
#         'key': 'VERB'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'X'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 4179,
#      'key': 'PUNCT'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 1,
#            'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'AUX'},
#        {'dirs': {'buckets': [{'doc_count': 16, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 16,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 5, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 6,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 3,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 5, 'key': '->'},
#           {'doc_count': 8, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 13,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 4, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 4,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 3, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 3,
#         'key': 'VERB'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 46,
#      'key': 'SCONJ'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 5,
#            'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 5,
#         'key': 'ADP'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'DET'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '->'},
#           {'doc_count': 4, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 6,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 11, 'key': '->'},
#           {'doc_count': 5, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 16,
#         'key': 'NUM'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 4, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 5,
#         'key': 'PUNCT'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 37,
#      'key': 'SYM'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 156,
#            'key': '->'},
#           {'doc_count': 284, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 440,
#         'key': 'ADJ'},
#        {'dirs': {'buckets': [{'doc_count': 47, 'key': '->'},
#           {'doc_count': 16, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 63,
#         'key': 'ADP'},
#        {'dirs': {'buckets': [{'doc_count': 1656, 'key': '->'},
#           {'doc_count': 615, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2271,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 178, 'key': '->'},
#           {'doc_count': 15, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 193,
#         'key': 'AUX'},
#        {'dirs': {'buckets': [{'doc_count': 979, 'key': '->'},
#           {'doc_count': 110, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1089,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 46, 'key': '->'},
#           {'doc_count': 29, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 75,
#         'key': 'DET'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'INTJ'},
#        {'dirs': {'buckets': [{'doc_count': 3345, 'key': '->'},
#           {'doc_count': 5367, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 8712,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 52, 'key': '->'},
#           {'doc_count': 57, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 109,
#         'key': 'NUM'},
#        {'dirs': {'buckets': [{'doc_count': 798, 'key': '->'},
#           {'doc_count': 141, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 939,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 1663, 'key': '->'},
#           {'doc_count': 725, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2388,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 330, 'key': '->'},
#           {'doc_count': 330, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 660,
#         'key': 'PROPN'},
#        {'dirs': {'buckets': [{'doc_count': 4394, 'key': '->'},
#           {'doc_count': 2620, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 7014,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 600, 'key': '->'},
#           {'doc_count': 208, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 808,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 3, 'key': '->'},
#           {'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 5,
#         'key': 'SYM'},
#        {'dirs': {'buckets': [{'doc_count': 1165, 'key': '->'},
#           {'doc_count': 1806, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2971,
#         'key': 'VERB'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'X'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 27740,
#      'key': 'VERB'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 1,
#            'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'ADJ'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'ADP'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 3, 'key': '->'},
#           {'doc_count': 6, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 9,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'VERB'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 14,
#      'key': 'X'},
#     {'ch_poses': {'buckets': [{'dirs': {'buckets': [{'doc_count': 1,
#            'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'ADJ'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 2,
#         'key': 'ADP'},
#        {'dirs': {'buckets': [{'doc_count': 10, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 11,
#         'key': 'ADV'},
#        {'dirs': {'buckets': [{'doc_count': 9, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 10,
#         'key': 'CCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'DET'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'INTJ'},
#        {'dirs': {'buckets': [{'doc_count': 2, 'key': '->'},
#           {'doc_count': 12, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 14,
#         'key': 'NOUN'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 3, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 4,
#         'key': 'NUM'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'PART'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '->'},
#           {'doc_count': 5, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 6,
#         'key': 'PRON'},
#        {'dirs': {'buckets': [{'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 1,
#         'key': 'PROPN'},
#        {'dirs': {'buckets': [{'doc_count': 21, 'key': '->'},
#           {'doc_count': 7, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 28,
#         'key': 'PUNCT'},
#        {'dirs': {'buckets': [{'doc_count': 3, 'key': '->'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 3,
#         'key': 'SCONJ'},
#        {'dirs': {'buckets': [{'doc_count': 5, 'key': '->'},
#           {'doc_count': 1, 'key': '<-'}],
#          'doc_count_error_upper_bound': 0,
#          'sum_other_doc_count': 0},
#         'doc_count': 6,
#         'key': 'VERB'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0},
#      'doc_count': 90,
#      'key': '_'}],
#    'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0}},
#  'hits': {'hits': [], 'max_score': 0.0, 'total': 70689},
#  'timed_out': False,
#  'took': 39}

# %% [markdown]
# Первые результаты показаны для прилагательного. И первый его потомок - другое прилагательное. Это немного странно. Посмотрим что за слова друг другу подчиняются и в каком предложении.
#
# При помощи `must` мы говорим БД, что мы объединяем несколько полей, которые должны быть в документе.

# %%
req={"query": {"bool": {"must":[{"match": {"child_PoS": "ADJ"}}, {"match": {"parent_PoS": "ADJ"}}]}}}
    
es.search(index = "syntagrus_rel", body = req)
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': 'pZUb_WgBjQGEBxqudDHa',
#     '_index': 'syntagrus_rel',
#     '_score': 5.7697906,
#     '_source': {'child': {'properties': {'PoS': 'ADJ',
#        'lemma': 'седой',
#        'tag': 'Case=Nom|Degree=Pos|Number=Plur',
#        'token': 'седые',
#        'wordPos': '13'}},
#      'child_PoS': 'ADJ',
#      'conn': 'conj',
#      'dir': '<-',
#      'parent': {'properties': {'PoS': 'ADJ',
#        'lemma': 'белый',
#        'tag': 'Case=Nom|Degree=Pos|Number=Plur',
#        'token': 'белые',
#        'wordPos': '10'}},
#      'parent_PoS': 'ADJ',
#      'sentID': 21},
#     '_type': 'relations'},
#    {'_id': 'epUb_WgBjQGEBxqutjgC',
#     '_index': 'syntagrus_rel',
#     '_score': 5.7697906,
#     '_source': {'child': {'properties': {'PoS': 'ADJ',
#        'lemma': 'требовательный',
#        'tag': 'Degree=Pos|Gender=Fem|Number=Sing|Variant=Short',
#        'token': 'требовательна',
#        'wordPos': '10'}},
#      'child_PoS': 'ADJ',
#      'conn': 'conj',
#      'dir': '->',
#      'parent': {'properties': {'PoS': 'ADJ',
#        'lemma': 'настойчивый',
#        'tag': 'Degree=Pos|Gender=Fem|Number=Sing|Variant=Short',
#        'token': 'настойчива',
#        'wordPos': '8'}},
#      'parent_PoS': 'ADJ',
#      'sentID': 76},
#     '_type': 'relations'},
#    {'_id': '-pUd_WgBjQGEBxquIljj',
#     '_index': 'syntagrus_rel',
#     '_score': 5.7697906,
#     '_source': {'child': {'properties': {'PoS': 'ADJ',
#        'lemma': 'прерывистый',
#        'tag': 'Case=Nom|Degree=Pos|Gender=Neut|Number=Sing',
#        'token': 'прерывистое',
#        'wordPos': '6'}},
#      'child_PoS': 'ADJ',
#      'conn': 'conj',
#      'dir': '<-',
#      'parent': {'properties': {'PoS': 'ADJ',
#        'lemma': 'горячий',
#        'tag': 'Case=Nom|Degree=Pos|Gender=Neut|Number=Sing',
#        'token': 'горячее',
#        'wordPos': '4'}},
#      'parent_PoS': 'ADJ',
#      'sentID': 425},
#     '_type': 'relations'},
#    {'_id': '5JUd_WgBjQGEBxqupGSX',
#     '_index': 'syntagrus_rel',
#     '_score': 5.7697906,
#     '_source': {'child': {'properties': {'PoS': 'ADJ',
#        'lemma': 'взволнованный',
#        'tag': 'Case=Nom|Degree=Pos|Gender=Neut|Number=Sing',
#        'token': 'взволнованное',
#        'wordPos': '4'}},
#      'child_PoS': 'ADJ',
#      'conn': 'conj',
#      'dir': '<-',
#      'parent': {'properties': {'PoS': 'ADJ',
#        'lemma': 'сосредоточенный',
#        'tag': 'Case=Nom|Degree=Pos|Gender=Neut|Number=Sing',
#        'token': 'Сосредоточенное',
#        'wordPos': '1'}},
#      'parent_PoS': 'ADJ',
#      'sentID': 569},
#     '_type': 'relations'},
#    {'_id': 'WJUb_WgBjQGEBxqutDg_',
#     '_index': 'syntagrus_rel',
#     '_score': 5.711979,
#     '_source': {'child': {'properties': {'PoS': 'ADJ',
#        'lemma': 'бесхарактерный',
#        'tag': 'Case=Nom|Degree=Pos|Gender=Fem|Number=Sing',
#        'token': 'бесхарактерная',
#        'wordPos': '6'}},
#      'child_PoS': 'ADJ',
#      'conn': 'conj',
#      'dir': '<-',
#      'parent': {'properties': {'PoS': 'ADJ',
#        'lemma': 'слабовольный',
#        'tag': 'Case=Nom|Degree=Pos|Gender=Fem|Number=Sing',
#        'token': 'Слабовольная',
#        'wordPos': '2'}},
#      'parent_PoS': 'ADJ',
#      'sentID': 73},
#     '_type': 'relations'},
#    {'_id': '6JUc_WgBjQGEBxqug0n-',
#     '_index': 'syntagrus_rel',
#     '_score': 5.711979,
#     '_source': {'child': {'properties': {'PoS': 'ADJ',
#        'lemma': 'решительный',
#        'tag': 'Case=Ins|Degree=Pos|Gender=Fem|Number=Sing',
#        'token': 'решительной',
#        'wordPos': '8'}},
#      'child_PoS': 'ADJ',
#      'conn': 'conj',
#      'dir': '<-',
#      'parent': {'properties': {'PoS': 'ADJ',
#        'lemma': 'смелый',
#        'tag': 'Case=Ins|Degree=Pos|Gender=Fem|Number=Sing',
#        'token': 'смелой',
#        'wordPos': '6'}},
#      'parent_PoS': 'ADJ',
#      'sentID': 288},
#     '_type': 'relations'},
#    {'_id': 'HJUb_WgBjQGEBxquoTZT',
#     '_index': 'syntagrus_rel',
#     '_score': 5.711979,
#     '_source': {'child': {'properties': {'PoS': 'ADJ',
#        'lemma': 'худенький',
#        'tag': 'Case=Gen|Degree=Pos|Gender=Fem|Number=Sing',
#        'token': 'худенькой',
#        'wordPos': '30'}},
#      'child_PoS': 'ADJ',
#      'conn': 'conj',
#      'dir': '<-',
#      'parent': {'properties': {'PoS': 'ADJ',
#        'lemma': 'робкий',
#        'tag': 'Case=Gen|Degree=Pos|Gender=Fem|Number=Sing',
#        'token': 'робкой',
#        'wordPos': '28'}},
#      'parent_PoS': 'ADJ',
#      'sentID': 57},
#     '_type': 'relations'},
#    {'_id': '9ZUc_WgBjQGEBxquDz4_',
#     '_index': 'syntagrus_rel',
#     '_score': 5.711979,
#     '_source': {'child': {'properties': {'PoS': 'ADJ',
#        'lemma': 'блестящий',
#        'tag': 'Case=Nom|Degree=Pos|Gender=Masc|Number=Sing',
#        'token': 'блестящий',
#        'wordPos': '17'}},
#      'child_PoS': 'ADJ',
#      'conn': 'conj',
#      'dir': '<-',
#      'parent': {'properties': {'PoS': 'ADJ',
#        'lemma': 'полный',
#        'tag': 'Case=Nom|Degree=Pos|Gender=Masc|Number=Sing',
#        'token': 'полный',
#        'wordPos': '11'}},
#      'parent_PoS': 'ADJ',
#      'sentID': 169},
#     '_type': 'relations'},
#    {'_id': 'HpUd_WgBjQGEBxquQl1r',
#     '_index': 'syntagrus_rel',
#     '_score': 5.711979,
#     '_source': {'child': {'properties': {'PoS': 'ADJ',
#        'lemma': 'собранный',
#        'tag': 'Case=Nom|Degree=Pos|Gender=Masc|Number=Sing',
#        'token': 'собранный',
#        'wordPos': '24'}},
#      'child_PoS': 'ADJ',
#      'conn': 'conj',
#      'dir': '<-',
#      'parent': {'properties': {'PoS': 'ADJ',
#        'lemma': 'уверенный',
#        'tag': 'Case=Nom|Degree=Pos|Gender=Masc|Number=Sing',
#        'token': 'уверенный',
#        'wordPos': '20'}},
#      'parent_PoS': 'ADJ',
#      'sentID': 462},
#     '_type': 'relations'},
#    {'_id': 'FJUb_WgBjQGEBxqusjgx',
#     '_index': 'syntagrus_rel',
#     '_score': 5.703279,
#     '_source': {'child': {'properties': {'PoS': 'ADJ',
#        'lemma': 'квалифицированный',
#        'tag': 'Case=Nom|Degree=Pos|Gender=Masc|Number=Sing',
#        'token': 'квалифицированный',
#        'wordPos': '8'}},
#      'child_PoS': 'ADJ',
#      'conn': 'conj',
#      'dir': '<-',
#      'parent': {'properties': {'PoS': 'ADJ',
#        'lemma': 'честный',
#        'tag': 'Case=Nom|Degree=Pos|Gender=Masc|Number=Sing',
#        'token': 'честный',
#        'wordPos': '6'}},
#      'parent_PoS': 'ADJ',
#      'sentID': 71},
#     '_type': 'relations'}],
#   'max_score': 5.7697906,
#   'total': 31},
#  'timed_out': False,
#  'took': 4}

# %% [markdown]
# Для выведенных предложений посмотрим их пару и предложение, в которое они входят.

# %%
def printStrangeRelation(ch_PoS, p_PoS, sentID):
    req={"query": {"bool": {"must":[{"match": {"child_PoS": ch_PoS}}, {"match": {"parent_PoS": p_PoS}}, {"match": {"sentID":sentID}}]}}}
    res1=es.search(index = "syntagrus_rel", body = req)
    print(res1["hits"]["hits"][0]["_source"]["child"], res1["hits"]["hits"][0]["_source"]["dir"], res1["hits"]["hits"][0]["_source"]["parent"])
    res=es.search(index = "syntagrus", body = {"query":{"match": {"sentID":sentID}}, "sort":"wordPos", "size":1000})
    print([(r["_source"]["token"], r["_source"]["wordPos"]) for r in res["hits"]["hits"]])

# %%
printStrangeRelation('ADJ', 'ADJ', 71)
# Out:
# {'properties': {'wordPos': '8', 'token': 'квалифицированный', 'lemma': 'квалифицированный', 'PoS': 'ADJ', 'tag': 'Case=Nom|Degree=Pos|Gender=Masc|Number=Sing'}} <- {'properties': {'wordPos': '6', 'token': 'честный', 'lemma': 'честный', 'PoS': 'ADJ', 'tag': 'Case=Nom|Degree=Pos|Gender=Masc|Number=Sing'}}
# [('Он', '1'), ('сказал', '2'), (',', '3'), ('что', '4'), ('Ефимова', '5'), ('честный', '6'), (',', '7'), ('квалифицированный', '8'), ('работник', '9'), (',', '10'), ('и', '11'), ('выразил', '12'), ('готовность', '13'), ('дать', '14'), ('ей', '15'), ('характеристику', '16'), ('.', '17')]

# %% [markdown]
# Интересная логика, но почему нет.
